# %% [markdown]
# <a href="https://colab.research.google.com/github/noambassat/SupremeCourtClassifier/blob/main/2_first_classifier_Train_last_no_CUTTING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Embedding + first classifier

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoModel
import torch
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate, cross_val_score, StratifiedKFold,train_test_split,cross_val_predict
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score,make_scorer, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from imblearn.under_sampling import RandomUnderSampler

# %%
data = pd.read_csv("dca_for_classifier.csv")

# %%
# ביטוי לבדיקה
keyword = "העותק כפוף לשינויי עריכה וניסוח"

# בדיקה אילו שורות מכילות את הביטוי
rows_with_keyword = data["גוף המסמך"].str.contains(keyword, na=False)

# סינון שורות שלא מכילות את הביטוי
filtered_data = data[rows_with_keyword]

# הדפסת השורות שלא מכילות את הביטוי
rows_without_keyword = data[~rows_with_keyword]
print("שורות שלא מכילות את הביטוי:\n")
print(rows_without_keyword["גוף המסמך"].to_string(index=False))

# הדפסת מספר השורות שנמחקו
num_removed = len(rows_without_keyword)
print(f"\nמספר השורות שנמחקו: {num_removed}")

# שמירת הנתונים המסוננים לקובץ חדש
filtered_data.to_csv("filtered_data.csv", index=False, encoding='utf-8')
print("\nהנתונים המסוננים נשמרו לקובץ: 'filtered_data.csv'")

data = filtered_data
# Out:
# שורות שלא מכילות את הביטוי:
#
# ['פסק-דין בתיק רע"פ 7861/03 בבית המשפט העליון ר...
# ['פסק-דין בתיק רע"פ 2038/04 בבית המשפט העליון ר...
# ['פסק-דין בתיק רע"פ 5978/04 בבית המשפט העליון ר...
#
# מספר השורות שנמחקו: 3
#
# הנתונים המסוננים נשמרו לקובץ: 'filtered_data.csv'

# %%
data
# Out:
#                                              גוף המסמך מספר תיק  \
# 1    ['פסק-דין בתיק רע"פ 8337/04 בבית המשפט העליון ...  8337/04
# 2    ['החלטה בתיק רע"פ 7896/04 בבית המשפט העליון רע...  7896/04
# 5    ['החלטה בתיק רע"פ 2985/04 בבית המשפט העליון בי...  2985/04
# 6    ['החלטה בתיק רע"פ 110/04 בבית המשפט העליון רע"...   110/04
# 7    ['פסק דין בתיק רע"פ 2929/04 בבית המשפט העליון ...  2929/04
# ..                                                 ...      ...
# 726  ['החלטה בתיק רע"פ 3076/07 בבית המשפט העליון רע...  3076/07
# 727  ['החלטה בתיק רע"פ 6415/07 בבית המשפט העליון רע...  6415/07
# 728  ['החלטה בתיק רע"פ 825/07 בבית המשפט העליון רע"...   825/07
# 729  ['החלטה בתיק רע"פ 4180/07 בבית המשפט העליון רע...  4180/07
# 730  ['החלטה בתיק רע"פ 8880/07 בבית המשפט העליון רע...  8880/07
#
#                                        Outcome of case  binary_outcome
# 1                                                  G R             1.0
# 2                                                  G A             1.0
# 5                                                  G A             1.0
# 6                                                  G A             1.0
# 7    G R substential matter that was resolved with ...             1.0
# ..                                                 ...             ...
# 726                                                  D             0.0
# 727                                                D A             0.0
# 728                                                D A             0.0
# 729                                                D A             0.0
# 730                                                D A             0.0
#
# [728 rows x 4 columns]

# %%
binary_counts = data['binary_outcome'].value_counts()
print(binary_counts)
labels = ['Denied (0)','Granted (1)']

plt.figure(figsize=(6, 6))
plt.pie(binary_counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#ff9999'])
plt.title('Outcome of Case (Binary Representation)')

plt.show()
# Out:
# binary_outcome
# 0.0    680
# 1.0     43
# Name: count, dtype: int64

# %%
# הגדרת פונקציה לעיצוב טקסט
def format_text(text, line_length=80):
    """
    פורמט טקסט כך שיהיה נוח לקריאה עם שורות שאורכן מוגבל.
    """
    import textwrap
    return "\n".join(textwrap.wrap(text, width=line_length))

# %%
tokenizer = AutoTokenizer.from_pretrained("dean-ai/sentence_transformer_Legal-heBERT")
model = AutoModel.from_pretrained("dean-ai/sentence_transformer_Legal-heBERT")

# %%
# פונקציה שמקבלת טקסט ומחזירה את האימבדינג כוקטור
def get_embeddings(text):
    # המרת הטקסט לפורמט מתאים למודל
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    # חישוב האימבדינג של המודל
    outputs = model(**inputs)
    # חישוב ממוצע הוקטורים עבור כל טקסט
    embeddings = outputs.last_hidden_state.mean(dim=1).detach().numpy()
    return embeddings[0]

# %% [markdown]
# ## Only last paragraph modeling

# %%
# פונקציה לחיתוך הטקסט בהתאם לכללים
def trim_text(text):
    min_length = 1000  # אורך מינימלי לשמירה
    last_sen = 50     # מספר תווים להסרה מסוף הטקסט

    # שמירת אורך מקורי לאבחון
    original_length = len(text)

    # הסרת מספר תווים מסוף הטקסט
    text = text[:-last_sen]

    # חיתוך ל-min_length האחרונים אם הטקסט ארוך יותר מהמינימום
    if len(text) > min_length:
        text = text[-min_length:]

    # הדפסת פידבק רק אם הטקסט עבר שינוי
    if len(text) != original_length:
        print(f"Trimmed Text (Original Length: {original_length}, Trimmed Length: {len(text)}):")
        formatted_text = "\n".join([text[i:i+80] for i in range(0, len(text), 80)])
        print(formatted_text)
        print("##*******************************************************####")
    return text


# הסרת שורות עם ערכים חסרים בעמודת הטקסט או בעמודת המטרה
data = data.dropna(subset=["גוף המסמך", "binary_outcome"])

# חיתוך הטקסטים בעמודת "גוף המסמך"
data["גוף המסמך"] = data["גוף המסמך"].apply(trim_text)

# שמירת התוצאה לקובץ
file_path = 'final_trimmed_data.csv'
data.to_csv(file_path, index=False, encoding='utf-8')

print(f"הקובץ נשמר בהצלחה בנתיב: {file_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
#  הבקשה להידחות גם לעצם העניין. המבקשהפגין התייחסות מזלזלת כלפי בתי המשפט, אשר בא
# ה לידי ביטוי באי-התייצבותו לדיוניםבשתי הערכאות הקודמות. יתרה מכך, עברו התעבורתי
# של המבקש כולל 107 הרשעות קודמות, ובניהן11 הרשעות קודמות בעבירה נשוא הדיון הנוכחי
# . נהיגה ללא רישיון נהיגה תקף במשך שבעהחודשים הינה עבירה חמורה וזאת משום שנושאים
# חיוניים הנוגעים לבטיחותו של הרכב אינםנבדקים ומשכך, פוטנציאלית, הרכב מסכן את הנוס
# עים בו, לרבות המבקש וכלי רכב אחריםהנוסעים בכביש. על-כן, אין מנוס מהרתעה ממשית, ב
# דרך של שלילת רישיון לתקופה ארוכה. אשר-על-כן, בקשת רשות הערעור נדחית. ניתנה היום,
#  ג\' באלול תשס"ו(27.8.06) שו פ ט _________________________העותק כפוף לשינויי ערי
# כה וניסוח. 06067350_H01.doc רגמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 7610, Trimmed Length: 1000):
#  דיןבקשת רשות הערעור להידחות. סעיף 74(ה) לחוק סדר הדין הפלילי (נוסחמשולב), תשמ"ב
# -1982 קובע: "74. עיון בחומר החקירה ...(ה) עלהחלטת בית משפט לפי סעיף זה ניתן לערו
# ר לפני בית המשפט שלערעור שידון בערר בשופטאחד." מסעיף זה למדים, כי על החלטה בעניי
# ניםהנוגעים לעיון בחומר חקירה, מוקנית הזכות לערר אחד בלבד (ראו גם רע"פ 4207/96מדי
# נת ישראל נ\' פרידן (לא פורסם); רע"פ 1535/01 התובע הצבאי הראשי נ\' כהן (לא פורסם)
# ; בש"פ 997/04 יעקובוביץ נ\' מדינת ישראל ואח\', פ"ד נח(3) 241; בש"פ 3837/05מגדל ה
# זוהר לבנין בע"מ נ\' מדינת ישראל ואח\' (לאפורסם)). ברע"פ 4207/96 מדינת ישראל נ\'
# פרידן (לא פורסם) נקבע, כי סעיף 74 לחוק סדרהדין הפלילי אינו מקנה זכות "להשיג על ה
# חלטת בית המשפט שלערעור שניתנה בביתהמשפט המחוזי על דרך של בקשת רשות לערער בבית המ
# שפט העליון" וכי: "אין לך זכות ערעור אלא אם כן קבע המחוקק הראשי ערכאה המוסמכתלדון
#  בערעור או בערר". סוף דבר: מטעמים אלה כולם, בקשת רשותהערעור נדחית. ניתנה היום, כ
# "א בתמוז תשס"ו(17.7.06). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06049530_H02.doc דפמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 354, Trimmed Length: 304):
# ['החלטה בתיק רע"פ 1787/06 בבית המשפט העליון רע"פ 1787/06 - ד\' בפני: כבוד השופט
# ס\' ג\'ובראן המבקש: אורי צונה נ ג ד המשיבה: מדינת ישראל בקשה לעיון חוזר החלטה הב
# קשה נדחית. ניתנה היום, כ"ב בתמוז תשס"ו(18.7.06). שו פ ט ________________________
# _העותק כפוף לשינויי עריכה וניסוח. 06017870_H08.doc רגמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 3883, Trimmed Length: 1000):
# ) (להלן: עניין לוין): "מקובל, כי אין מנוס, מקביעת עונש מרתיע בעבירות כגון גרם מו
# ותברשלנות, על מנת לשקף את החומרה הטמונה בעבריינות הכביש אשר אחראית לקורבנות רבים
# מספור. ואכן, על-פי רוב, מחייבת הרשעה בעבירה של גרם מוות ברשלנות השתת עונש חמור,ה
# כולל הורדתו של הנהג, אשר ביצע עבירה זו, מן הכביש לתקופה ארוכה והשתת עונש מאסרבפו
# על. אולם כאמור, אין זהו כלל חלוט ובהחלט ייתכן, כי שיקולי צדק יעמידו בפנינועילה ל
# התערבות ולהקלה בעונש." בנסיבות המקרה שבפנינו, לא מצאתי את אותןנסיבות חריגות ויוצ
# אות דופן, דוגמת אלו שנמצאו בעניין לוין, אשריתירו, משיקולי צדק, חריגה מההלכה, לפי
# ה יש להטיל על מי שהורשע בגרימת מוות בתאונתדרכים בשל רשלנותו עונש משמעותי, הכולל
# מאסר בפועל. אשר-על-כן, הבקשה למתן רשות ערעור נדחית. החלטתי מיום 8.2.2006 בעניין
# עיכוב ביצועעונש המאסר – מבוטלת. המבקש יתייצב ביום 4.7.2006 לא יאוחרמהשעה 10:00,
# במזכירות בית-המשפט המחוזי בתל-אביב-יפו, לשם תחילת ריצוי עונשו. ניתנה היום, י"ח ב
# סיוון תשס"ו(14.6.2006). ש ו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06012390_H02.doc דממרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2455, Trimmed Length: 1000):
# בקשה זו מייסדת עצמה על טענה עיקרית, היא טענת ההגנה מן הצדק אותה העלו, ושבו והעלו
# , המבקשים בשתי הערכאות קמא. לאחר שעיינתי בבקשה ובנספחים שצורפו לה, באתי לכלל מסק
# נה כי דינה להידחות על הסף. זאת, היות שכל הנטען בה מוגבל לענינם המסוים של המבקשים
# , ואין היא מעלה שאלות שלבירורן חשיבות משפטית כללית. לפיכך נמצא, על-פי ההלכה הנוה
# גת עמנו, כי אין כל עילה לברר את הסוגיה בשלישית (ר"ע 103/82 חניון חיפה בע"מ נ\' מ
# צת אור (הדר חיפה) בע"מ, פ"ד לו(3), 123). באשר לעונש שנגזר, לא זו בלבד שגם בסוגיה
#  זו לא ניתנת בדרך כלל רשות לערעור נוסף (רע"פ 10231/03 קורן נ\' מדינת ישראל, פ"ד
# נח(1) 646, 650), אלא שגם לגופם של דברים איני רואה ממה יוכלו המבקשים להיבנות בטוע
# נם, כי במקרה אחר היה העונש שנגזר קל יותר. כידוע, כל מקרה נבחן לגופו, וכל נאשם ונ
# סיבותיו. איני סבור, כי בגוזרה את העונש שגזרה שקללה הערכאה הדיונית את מכלול הנסיב
# ות בענינם של המבקשים שלא כראוי. על יסוד כל האמור, הבקשה נדחית. ניתנה היום, כ\' ב
# טבת התשס"ז (10.01.07). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 06105070_O01.doc אז מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 367, Trimmed Length: 317):
# ['החלטה בתיק רע"פ 4738/06 בבית המשפט העליון רע"פ 4738/06 - ב\' בפני: כבוד השופט
# ס\' ג\'ובראן המבקש: חיים הוכמן נ ג ד המשיבה: מדינת ישראל בקשה בהסכמה לעיכוב ביצו
# ע גזר דין החלטה כמבוקש. ניתנה היום, כ"ג בתשרי תשס"ז(15.10.06). שו פ ט __________
# _______________העותק כפוף לשינויי עריכה וניסוח. 06047380_H03.docהגמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 567, Trimmed Length: 517):
# ['החלטה בתיק רע"פ 5488/06 בבית המשפט העליון רע"פ 5488/06 בפני: כבוד השופט ד\' חש
# ין המבקש: אבי עמר נ ג ד המשיבה: מדינת ישראל בקשה נוספת לדחיית מועד התייצבות לריצ
# וי עונש מאסר בשם המבקש: עו"ד יוסי אביטל החלטה מותב זה אינו יושב כערכאת ערעור עלה
# חלטותיו של מותב אחר בבית משפט זה. משנדחתה בקשתו של המבקש לעיכוב נוסףבביצוע העונש
#  (ביום 5.10.06), אינני רואה מקום להיעתר לבקשה. הבקשה נדחית. ניתנה היום, כ\' בתשר
# יתשס"ז (12.10.2006).ש ו פ ט _________________________העותק כפוף לשינויי עריכה ונ
# יסוח. 06054880_F05.doc עכבמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 6982, Trimmed Length: 1000):
#  בית-משפט השלום. דין הבקשה להידחות גם בכל הנוגעלגזר-הדין. הלכה היא, כי טענות בנו
# גע לחומרת העונש כשלעצמה, אינן מקימות עילה למתןרשות ערעור בפני בית-משפט זה, אלא ב
# נסיבות של סטייה ניכרת ממדיניות הענישה (ראורע"פ 1174/97 עזרא רפאלי נ\' מדינת ישרא
# ל (לא פורסם);רע"פ 7201/97 דב בשירי נ\' היועץ המשפטי לממשלה (לא פורסם)).בענייננו,
#  העונש שהוטל על המבקשים אינו חורג ממתחם הענישה המקובל בעבירות מהסוגשביצע ונסיבות
#  המקרה אינן מצדיקות התערבות בית-משפט זה. גם לגופו של עניין, בית-משפט זה פסק לאפע
# ם, כי בעבירות כלכליות, בהן מדובר במעשים שהינם תוצאה של תכנון ומחשבה ונובעיםמתאוו
# ת בצע, גובר משקלו של השיקול ההרתעתי על משקלן של נסיבותיו האישיות (ראוע"פ 624/80
# חב\' וייס ארנסט בע"מ נ\' מדינת ישראל,פ"ד לה (3) 211; ע"פ 6474/03 מלכה נ\' מדינת
# ישראל (לאפורסם)). איני רואה כל מקום לסטות מהלכה זו במקרה דנן. אשר-על-כן, הבקשה ל
# מתן רשות ערעור נדחית,על שני חלקיה ועמה מתייתרת הבקשה לעיכוב ביצוע. ניתנה היום, ו
# \' באב תשס"ו(31.7.2006). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06062180_H01.doc דממרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 1749, Trimmed Length: 1000):
# יוחסה לו עבירה של החזקת סם לצריכה עצמית, נגזרו למבקש 12 חודשימאסר בפועל ושני מאס
# רים על-תנאי בני שנה בסך הכל. ערעורו לבית-המשפט המחוזיבבאר-שבע (כבוד הנשיא י\' פל
# פל והשופטים י\' אלון ונ\' זלוצ\'ובר) נדחה, לאחר שלא נמצאמקום להתערב בממצאי עובדה
#  ומהימנות שנקבעו בערכאה הדיונית. באשר לעונש, נקבע כי זההלם את חומרת המעשים, את כ
# מות הסם הגדולה שנתפסה ואת גיוונו, כמו גם את התסקירהשלילי שהוגש בענינו של המבקש מ
# טעם שירות-המבחן. בבקשה שבפני עותר המבקש, שאינו מיוצגוכבר החל לשאת בעונשו, להתיר
# לו לערער בשנית על גזר-הדין. לאחר שעיינתי בבקשה ובנספחיה, הגעתי לכללדעה כי דינה ל
# הדחות. ענינו של המבקש אינו נמנה עם אותם מקרים חריגים, בהם מקימהמידת העונש שנגזר
# עילה לקיומו של דיון נוסף, שלישי במספר, בפני בית-משפט זה. הפרשהנבחנה בידי שתי ערכ
# אות שיפוטיות, ואף אני מצאתי – מן הטעמים שפורטו בהכרעותיהן, כיהעונש שנגזר למבקש א
# ינו חורג לחומרה מן הראוי בנסיבות המקרה. אשר-על-כן, הבקשה נדחית. ניתנה היום, כ"ה
# בניסן תשס"ו(23.4.2006). ש ו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06014470_O01.doc/שבמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 6064, Trimmed Length: 1000):
# טרותיה, הרי שמדובר בעבירה אשרנמשכה זמן רב, תוך ידיעה, כי מדובר בעבירה חמורה. על
# שיקול זה יש להוסיף את מעשהוהחמור עוד יותר של המבקש, אשר ניסה לחבל במאמציהם של כו
# חות הביטחון לתפוס את פאוזןולמנוע את הסכנה הציבורית הנשקפת ממנו. בהלכת אבו סאלם ק
# בעבית-המשפט, כי: "טרם בשלה העת לשינוי מדיניות הענישה המחמירה בעבירות נושא הדיוןב
# רוח הלכתח\'טיב.מעשי הטרור הקשים עדיין מכים במדינה; הסיכון הטמון בהסעתם, בהלנתם ו
# בהעסקתם שלשוהים בלתי חוקיים המגיעים לישראל משטחי יהודה, השומרון וחבל עזה לא נתפו
# גג; ומכאןששיקולי הרתעה- הרתעת היחיד והרתעת הרבים- עדיין שיקולים הם ממעלה עליונה"
# . כוחם של דברים אלו יפה גם היום ואולי אףביתר שאת, לאור המצב הביטחוני הרגיש בו מצ
# ויה המדינה. אשר-על-כן, הבקשה למתן רשות ערעור נדחית. החלטתי מיום 16.2.2006, בעניי
# ן עיכובביצוע גזר-הדין, מבוטלת. על המבקש להתייצב ביום 2.7.2006 לא יאוחרמהשעה 10:0
# 0 במזכירות בית-המשפט המחוזי בתל-אביב-יפו, לשם תחילת ריצוי עונשו. ניתנה היום, י"ב
#  בסיוון תשס"ו(8.6.2006). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06015050_H02.doc אתמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 3473, Trimmed Length: 1000):
# ענות בנוגע לחומרתהעונש כשלעצמה, אינן מקימות עילה למתן רשות ערעור בפני בית-משפט ז
# ה, אלא בנסיבותשל סטייה ניכרת ממדיניות הענישה (ראו רע"פ 1174/97 עזרא רפאלי נ\' מד
# ינת ישראל (לא פורסם); רע"פ 7201/97 דב בשירי נ\' היועץ המשפטי לממשלה (לא פורסם)).
#  דין הבקשה להדחות גם לגופו של עניין.למבקש הרשעות קודמות בגין עבירות לפי חוק הכני
# סה לישראל, ואף נגזרו עליו בעברעונשי מאסר בפועל בגין ביצוע עבירות דומות. את המעשי
# ם נשוא בקשה זו, ביצע המבקשכחצי שנה בלבד לאחר שהשתחרר ממאסר, וביודעו כי עומדים לח
# ובתו שני עונשי מאסר עלתנאי בני הפעלה. התנהגות זו של המבקש מצביעה על זלזול בהחלטו
# ת בתי-המשפט ובמערכתאכיפת החוק. העונש שהוטל על המבקש הולם את חומרת העבירות בהן הו
# רשע, וכן אתנסיבותיו האישיות של המבקש. אף טענתו של המבקש, כי הוא עומד להינשא לאזר
# חיתישראלית, אין בה כדי להוות טעם להקלה בעונשו. בנסיבות אלו, לא מצאתי מקום להתערב
# בפסק-דינו של בית-המשפט המחוזי. אשר-על-כן, בקשת רשות הערעור נדחית. ניתנה היום, כ"
# ז באלול תשס"ו (20.9.06). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06055740_H05.doc אתמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 4925, Trimmed Length: 1000):
#  פורסם)). בענייננו, העונש שהוטל על המבקש אינו חורגממתחם הענישה המקובל בעבירות מה
# סוג שביצע ונסיבות המקרה אינן מצדיקות התערבותבית-משפט זה. דין הבקשה להידחות גם לע
# צם העניין. לממונהזכות על-פי חוק סעיף 51ב\' לחוק העונשין, תשל"ז-1977 להמליץ על הת
# אמתו שלנידון למאסר לביצועו בעבודות שירות, ובאיזה עבודה. המלצה זו לא הוגבלה בחוק
# לתחוםמסוים, רפואי או אחר ועל-כן לממונה זכות מלאה לשקלל גם נתונים אחרים, כמו התנה
# גותובעבר של הנידון. ראוי לציין, כי בית-המשפט אכן איננו כבול להמלצה זו של הממונהו
# ההסתמכות הרחבה על המלצתו נובעת מאמונו בהתנהלותו ובשיקוליו המקצועיים. גם המלצתושל
#  הממונה במקרה דנן מבוססת היטב היא על ניסיון העבר, באשר המבקש בהתנהגותו הוא זהאשר
#  מנע מעצמו את האפשרות לבצע את עבודות השירות. העבירות בהן הורשע המבקש הינן עבירות
# חמורות, גם בהיבט התעבורתי וגם בהיבט הציות הכללי לחוק ועל בית-המשפט לנקוטבמדיניות
#  ענישה מרתיעה בעבירות אלה. אשר-על-כן, הבקשה למתן רשות ערעור נדחית. ניתנה היום, י
# "ג בניסן תשס"ו (11.4.2006). שו פ ט _________________________העותק כפוף לשינויי ע
# ריכה וניסוח. 06029940_H02.docמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 8326, Trimmed Length: 1000):
# מום הנדרש ממי שהוטל עליו צו שירות. כידוע, בית-משפט שלערעור אינו מתערב בממצאים עו
# בדתיים שקבעה הערכאה הדיונית, זאת במיוחד כאשר מדובר בבקשת רשות ערעור (ראו, למשל,
# ע"פ 1258/03 פלוני נ\' מדינת ישראל, פ"ד נח(6) 625, בעמ\' 631-632). בנסיבות אלה, א
# ף בטענה זו לא מצאתי כל עילה להתערבותו של בית-משפט זה. מנסיבות המקרה עולה, כי בצד
# ק קבעו הערכאות הקודמות, כי התנהגות המבקש מלמדת, כי לא הפנים את הלקח, לא שיתף פעו
# לה עם שירות המבחן, לא הפיק את מידת הרחמים שננקטה כלפיו ולא ניצל את ההזדמנות שנית
# נה לו, כל זאת לאחר שהתחייב לעמוד במשימתו וכשהוא ערב הסמכה לעריכת-דין. למעשה, בחר
#  המבקש שלא לעשות דבר. כך למשל, הוא לא פנה בכתב לשירות המבחן בבקשה למתן אורכה ולא
#  פנה לבית-המשפט להודיע כי בשל נסיבות כאלו ואחרות נבצר ממנו לקיים את צו המבחן. בנ
# סיבות אלה, שוכנעתי, כי אין למבקש להלין אלא על עצמו. אשר-על-כן, בקשת רשות הערעור
# נדחית. המזכירות תשלח העתק מהחלטתי זו לממונה על עבודות שירות. ניתנה היום, ל\' בשב
# ט התשס"ז (18.2.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכה
#  וניסוח. 06100260_H02.doc /צש מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 3121, Trimmed Length: 1000):
# לערער על פסק-דין בהליך פלילי קמה משעה שבית-המשפטקם מכיסאו, ובלשונו של הנשיא מ\'
# שמגר: "אם נותר לשופט לעשות דבר מה נוסף, איןהחלטתו בגדר פסק-דין. משסיים השופט את
# מלאכתו, נפתחים בפני בעל דין, הרואה עצמומקופח, שעריו של בית המשפט לערעורים" (ע"פ
# 1509/91 כדורי נ\'מדינת ישראל,פ"ד מה (3) 652, 655). והנה, גזירת עונשו של מי שהורש
# ע והתבקשה בעניינו חוותדעת מהממונה על עבודות השירות, אינה נשלמת קודם שהוגשה חוות
# הדעת, ובטרם הכריעבית-המשפט בדבר האופן בו ישא הנאשם בעונש (רע"פ 2288/06 סיאני נ\'
# מדינת ישראל(טרם פורסם); ע"פ 537/89 מדינתישראל נ\' אברהמין,פ"ד מג(4) 772; ע"פ 127
# 6/95 מדינת ישראל נ\' בעדש (לא פורסם); רע"פ271/01 טולדנו נ\' מדינת ישראל, פ"ד נה(
# 3) 830(. למותר לציין, כי לאחר שבית-המשפט המחוזיייתן החלטתו באשר לאופן בו יירצה ה
# מבקש את עונשו ופסק-דינו ייהפך לסופי, תהא פתוחהבפני המבקש הדרך לפנות לבית-משפט זה
#  בבקשת רשות ערעור חדשה, באם יהיה מעוניין בכך. הבקשה נדחית, איפוא. ניתנה היום, כ"
# ג בתשרי תשס"ז(15.10.06). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06064890_H02.doc קקמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 1717, Trimmed Length: 1000):
# הכיתוב הגזעני "איןערבים – אין פיגועים". בפסק-דינו הורה בית-המשפט המחוזי עלהחזרת
# הענין לבית-משפט השלום למען יגזור למבקש את עונשו. לאחר שנגזר העונש – ארבעהחודשי מ
# אסר בפועל לריצוי בעבודות שירות, ששה חודשי מאסר על-תנאי וקנס בסך 500ש"ח, הוגשה לב
# ית-משפט זה הבקשה המקורית אשר, כפי שציינתי, נדחתה. בתוך כך,כמתברר, שוב הוגש ערעור
#  לבית-המשפט המחוזי בירושלים, הפעם הזו נגד חומרת העונש.בית-המשפט המחוזי (כבוד סגן
# -הנשיא צ\' סגל והשופטים ע\' חבש וי\' נועם) דחה את הערעורלאחר שמצא כי העונש שנגזר
#  לא חרג מרמת הענישה הראויה. מכאן הבקשה שבפני, המסבה עצמה אף היא עלחומרת העונש. ד
# א עקא, שהטעם שעמד בבסיס החלטתי בבקשתו הקודמת של המבקש תקף גם ביחסלעתירתו הנוכחית
# . כמצוין באותה החלטה, רשות להגשתו של ערעור שני שמורה לעניניםהמעלים שאלה משפטית כ
# ללית. התערבות בענינים פרטניים, לרבות במידתו של עונש שנגזר,שמורה למקרים חריגים בל
# בד. מקרהו של המבקש אינו נמנה עם אלה. מטעם זה, אני דוחה את הבקשה. ניתנה היום, י"א
#  בניסן תשס"ו(9.4.2006). ש ו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06021440_O01.doc/שבמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 4746, Trimmed Length: 1000):
# ייננו, בקשת רשות הערעור איננה מעוררת כל שאלה משפטיתעקרונית שכזו והמבקש לא הצביע
# על עילה המצדיקה דיון בגלגול שלישי, בהתאם להלכת חניון חיפה. זאת ועוד, הלכה היא, כ
# י טענות בנוגעלחומרת העונש כשלעצמה, אינן מקימות עילה למתן רשות ערעור בפני בית-משפ
# ט זה, אלאבנסיבות של סטייה ניכרת ממדיניות הענישה (ראו רע"פ 1174/97 עזרא רפאלינ\'
# מדינת ישראל, (לא פורסם); רע"פ 7201/97 דב בשירי נ\' היועץהמשפטי לממשלה, (לא פורסם
# )). בענייננו, העונש שהוטל על המבקש אינו חורגממתחם הענישה המקובל בעבירות מהסוג שב
# יצע ונסיבות המקרה אינן מצדיקות התערבותבית-משפט זה. דין הבקשה להידחות גם לעצם הענ
# יין. המבקשאינו מגלה כל מורא בפני החוק, וממשיך לעבור עליו כרצונו, תוך סיכון ופגיע
# ה באנשיםוברכושם. בנסיבות כאלו, הרחקתו מהחברה מתבקשת. הקנס שהוטל על המבקש אינו גב
# וה ביחסלשוויו של הרכוש אותו גנב או ניסה לגנוב ואין אני רואה מקום להתערב בעניין ז
# הבקביעתן של הערכאות שקדמו לי. סוף דבר, הבקשה למתן רשות ערעור נדחית. ניתנה היום,
# ד\' בניסן תשס"ו (2.4.2006). שו פ ט _________________________העותק כפוף לשינויי ע
# ריכה וניסוח. 06007570_H02.docמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 3655, Trimmed Length: 1000):
# בקש לאהצביע על עילה המצדיקה דיון "בגלגול שלילי", בהתאם להלכת חניון חיפה. כמו-כן,
#  הלכה היא, כי טענות בנוגע לחומרתהעונש כשלעצמה, אינן מקימות עילה למתן רשות ערעור
# בפני בית-משפט זה, אלא בנסיבותשל סטייה ניכרת ממדיניות הענישה (ראו רע"פ 1174/97 עז
# רא רפאלי נ\' מדינת ישראל (לא פורסם); רע"פ 7201/97 דב בשירי נ\' היועץ המשפטי לממש
# לה (לא פורסם)). בענייננו ולאור נסיבותהמקרה שבפנינו, העונש שהוטל על המבקש אינו מצ
# דיק התערבות בית-משפט זה. דין הבקשה להידחות גם לגופו של עניין. בית-המשפטהמחוזי קב
# ע, כי אין מדובר בנשק שנמסר למבקש כדין במהלך שירותו הצבאי ונשאר ברשותועקב טעות, א
# לא שמדובר בעבירה של החזקת נשק שלא כדין החשוד כגנוב. לכך יש להוסיף אתהעובדה, שהמב
# קש לא לקח אחריות למעשיו. בנסיבות אלה שוכנעתי, כי העונש שהוטל עליואינו חמור כלל ו
# עיקר וודאי שאינו חורג ממדיניות הענישה הראויה ועל כן אין מקוםלהתערבות בית-משפט זה
#  בפסק-דינו של בית-המשפט המחוזי. אשר-על-כן, בקשת רשות הערעור נדחית. ניתנה היום, י
# "ד בכסלו תשס"ז(5.12.06). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06099340_H01.doc דפמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2484, Trimmed Length: 1000):
#  ובא-כוחו דאז, הצטיירה התמונה כי מאז ביצוען של העבירות הנוכחיות עליהן הוא נקרא ל
# תת את הדין, חדל המבקש מביצוען של עבירות נוספות (ראו עמ\' 17 לפרוטוקול הדיון). טי
# עון זה היווה את אחד משיקוליה של הערכאה הדיונית, שבגזר דינה קבעה: "מאז המקרה (שאר
# ע לפני כשנתיים) לא נפתחו נגד הנאשם תיקים נוספים" (ההדגשה הוספה). במצב זה, משהובא
#  גזר הדין בפני בית המשפט המחוזי, היתה זו זכותה של המשיבה אם לא לומר חובתה, להביא
#  לידיעת בית המשפט כי אחד השיקולים שעמדו בבסיס הענישה בה נקט בית משפט השלום, היה
# שגוי. למעלה מן הדרוש נוסיף, כי גם בחינת העונש לגופו אינה מגלה כי נפלה בו שגגה. א
# דרבא, המבקש ביצע את העבירות הנוכחיות שעה שהיה משוחרר בתנאים מגבילים ומעל לראשו ר
# יחף מאסר על-תנאי. בנסיבות אלו העונש שהושת עליו הנו מתון ביותר, ומכאן החלטתנו לדח
# ות את הבקשה. המבקש יתייצב לשאת בעונשו במזכירות בית המשפט המחוזי בירושלים, ביום כ
# "ז בניסן התשס"ז (15.4.2007), עד לשעה 11:00. ניתנה היום, ג\' בניסן התשס"ז (22.03.
# 07). ש ו פ ט ש ו פ ט ת ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 06039600_O03.doc אז מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 4733, Trimmed Length: 1000):
# כתחניוןחיפה. השאלות המשפטיות אותן העלה בא-כוח המבקש מוכרות ואף נדונו והדבריםמובא
# ים בהרחבה בהחלטותיהם של בית-המשפט לעניינים מקומיים ובית-המשפט המחוזי. לענייננו,
# די אם נחזור ונדגיש את מטרתמנגנון צו ההריסה המנהלי, אשר נקבע על-ידי המחוקק במטרה
# להילחם בנגע הבנייה הבלתיחוקית (ראה: ר"ע 1/84 דוויק נ\' ראש העיר ירושלים,פ"ד לח (
# 1) 494; רע"פ 273/86 פרץ נ\' יו"ר הוועדה המקומיתלתכנון ולבנייה, פ"ד מ(2) 445 ,447
# .) כך נקבע על-ידי המחוקק,למעשה, כי אין זכות שימוע מקדמית וכי הנפגעים יוכלו לבקש
# מיוזמתם מבית-המשפט ביטולהצו. כך נקבע גם, כי אין צורך שהמהנדס יבקר אישית בכל אתר
# ואתר, אלא יוכל להסתמךעל תצלומים ותצהירים של מי מטעמו. הקלות אלו מאוזנות במקרים מ
# וגבלים, אשר בגינםניתן להוציא צו הריסה מנהלי, ובהתאם לפרוצדורה המדוקדקת הנדרשת על
# -מנת לעשות כן,כפי שנקבע בסעיף 238א לחוק. אשר-על-כן, הבקשה למתן רשות ערעור נדחית.
#  החלטתי מיום 14.3.2006 בדבר עיכוב ביצועצו ההריסה המנהלי מבוטלת בזאת. ניתנה היום,
#  כ"א באדר תשס"ו(21.3.2006). שו פ ט _________________________העותק כפוף לשינויי ע
# ריכה וניסוח. 06020340_H03.docמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 6892, Trimmed Length: 1000):
# נ\' מדינת ישראל (לאפורסם); רע"פ 7201/97 דב בשירי נ\' היועץ המשפטי לממשלה (לאפורס
# ם)). בענייננו, העונש שהוטל על המבקש אינו חורג ממתחם הענישה המקובל בעבירותמהסוג ש
# ביצע ונסיבות המקרה אינן מצדיקות התערבות בית-משפט זה. דין הבקשה להידחות גם לעצם ה
# עניין. המבקשהורשע בגין התנהגותו הבריונית הראויה לגנאי. החברה צריכה להוקיע ולהסתי
# יג מאדם אשרלאור היום נוטל סכין והולך להכות ולאיים על שכניו ללא מורא, שמא יאונה ל
# ו רע. כמו-כןחמור מאוד בעיניי הדבר, כי המבקש העז להעליב ולאיים על שוטר, אשר מילא
# את חובתו.כל אלה אינם עבירותיו היחידות של המבקש ובאמתחתו עבר פלילי מכביד. העבירות
#  בהןהורשע המבקש הינן עבירות חמורות ועל בית-המשפט לנקוט במדיניות ענישה מרתיעהבעבי
# רות אלה. אשר-על-כן, בקשת רשות הערעור נדחית. החלטתי מיום 26.4.06 - בעניין עיכובבי
# צוע עונש המאסר - מבוטלת. על המבקש להתייצב ביום 16.10.06 לא יאוחרמהשעה 10:00 במזכ
# ירות הפלילית של בית-המשפט המחוזי בתל-אביב-יפו, לשם תחילת ריצויעונשו. ניתנה היום,
#  י"ג באלול תשס"ו(6.9.06) שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06034740_H03.doc רגמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 7238, Trimmed Length: 1000):
# ט קמא הוסיף וקבע כי דרגת רשלנותם של המערערים היתה "גבוהה ביותר" וכי הם הסבו פניה
# ם מכל הסימנים המזהירים והמחשידים לגבי מטרותיו של היושב ברכבם, ובכלל זה: הזמנת הה
# סעה מראש, סיכום על מחיר נסיעה מופרז, איסוף הנוסע מפרצה בגדר ההפרדה והתנהגות חשוד
# ה של הנוסע לרבות החזקת תיק בידיו, שתיקה מתמשכת לאורך כל הנסיעה, אי-ידיעה מצדו לג
# בי יעד הנסיעה עד שנדרש ליצור קשר עם שני אנשים אחרים כדי לברר זאת. בית המשפט המחו
# זי פסק כי "רשלנות חמורה ונמשכת זו, אשר תרמה לביצוע פיגוע טרור רב-נפגעים, מחייבת
# את המסקנה כי לא \'מעשה אחד\' בפנינו לצורך הענישה, וכי ראוי והולם להורות על הצטבר
# ות הענישה". אין להתערב בקביעה זו, ובנסיבות המקרה, כפי שפורטו על-ידי הערכאות הקוד
# מות, גם אין להתערב בשיעור העונש שהוטל. התוצאה היא שהערעור נדחה. המשנה-לנשיאה השו
# פט ס\' ג\'ובראן: אני מסכים. ש ו פ ט השופט י\' אלון: אני מסכים. ש ו פ ט הוחלט כאמ
# ור בפסק-דינו של המשנה-לנשיאה א\' ריבלין. ניתן היום, י"ג בחשוון התשס"ח (25.10.07)
# . המשנה-לנשיאה ש ו פ ט ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 06041570_P05.doc גח מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 9626, Trimmed Length: 1000):
# , אף הן אינן מצדיקות את התערבותו של בית-משפט זה. הלכה היא, כי טענות בנוגעלחומרת
# העונש כשלעצמה, אינן מקימות עילה למתן רשות ערעור בפני בית-משפט זה, אלאבנסיבות של
# סטייה ניכרת ממדיניות הענישה (ראו רע"פ 1174/97 רפאלי נ\' מדינת ישראל (לא פורסם);
# רע"פ 7201/97 בשירי נ\' היועץ המשפטי לממשלה (לא פורסם)). מקרה זה אינו מקרהחריג, ה
# מצדיק סטייה מהלכה זו. העבירות שביצע המבקש, תוך ניצול מצבה של המתלוננתומעמדו כעור
# ך-דין, הינן חמורות מאד. על-אף חומרתן של העבירות, נסיבותיו האישיות שלהמבקש נלקחו
# בחשבון על-ידי בית-משפט השלום ועל-ידי בית-המשפט המחוזי, שאף בחר שלאלהחמיר בעונשו
# של המבקש למרות הרשעתו בעבירה נוספת. בנסיבות אלו, לא שוכנעתי כי ישמקום להקל בעונש
# ו של המבקש. אשר-על-כן, הבקשה למתן רשות ערעור נדחית. החלטתי מיום 30.1.06 – בעניין
#  עיכובביצוע עונש המאסר – מבוטלת. על המבקש להתייצב במזכירות בית-המשפטהמחוזי בירוש
# לים ביום 1.11.06 לא יאוחר מהשעה 10:00 לשם תחילת ריצוי עונשו. ניתנה היום, \u200fי
# "ב בתשרי תשס"ז(4.10.06). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06009460_H04.doc תומרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 595, Trimmed Length: 545):
# ['החלטה בתיק רע"פ 7359/06 בבית המשפט העליון רע"פ 7359/06 בפני: כבוד השופט ס\' ג\
# 'ובראן המבקש: בנימין מזרחי נגד המשיבה: מדינת ישראל בקשה לדחיית מועד התייצבות החל
# טה בהסכמת המשיבה, אני מחליט בזה כי על המבקש להתייצב ביום 6.5.07 לא יאוחר משעה 9:
# 00 במפקדת גוש עיירות של שירות בתי הסוהר, וזאת לשם קליטה ושיבוץ לענין ריצוי עונשו
#  בעבודות שירות, כפי שקבע בית המשפט המחוזי בהסתמך על חוות דעת הממונה על עבודות הש
# ירות. ניתנה היום, ל\' בשבט התשס"ז (18.2.2007). ש ו פ ט _________________________
#  העותק כפוף לשינויי עריכה וניסוח. 06073590_H05.doc /צש מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 6186, Trimmed Length: 1000):
#  7201/97 דב בשירי נ\' היועץהמשפטי לממשלה, (לא פורסם)). בענייננו, העונש שהוטל על
# המבקש אינו חורגממתחם הענישה המקובל בעבירות מהסוג שביצע ונסיבות המקרה אינן מצדיקו
# ת התערבותבית-משפט זה. דין הבקשה להידחות גם לעצם העניין. איןכל מקום להקל בעונשו ש
# ל המבקש לנוכח העבירות החמורות שביצע. יתר על כן, המבקשבהתנהגותו אפשר למעשה גם את
# האונס שבוצע על-ידי חברו באותה הזדמנות וכהמשך ישירלמעשיו. מקוממת במיוחד העובדה, ש
# המבקש בבקשת רשות הערעור, אף לא מצא לנכון להביערגשי חרטה על שורת העוולות שביצע. ה
# עונש הקל עד מאוד, שהטיל בית-משפט השלום עלהמבקש, לא שיקף כלל את חומרת מעשיו וטוב
# עשה בית-המשפט המחוזי משהחמיר עימו. לא זו אף זאת; המבקש סובל ממחלת נפש. יחדעם זאת
# , אין ראיה שהמבקש סבל ממחלת הנפש גם במועד ביצוע העבירות, או שהעבירות נבעוממחלת נ
# פש. מכל מקום, בית-המשפט המחוזי הבהיר, כי התחשב בעובדה זו בעת שגזר אתעונשו של המב
# קש, ושמכך, אין כל מקום להקלה נוספת. אשר-על-כן, בקשת רשות הערעורנדחית. ניתנה היום
# , כ"ז באב תשס"ו(21.8.06) שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06014800_H02.doc רגמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 6429, Trimmed Length: 1000):
#  קיצוניים, ערכאת הערעור תקבל את קביעות הערכאה הדיונית אשר התרשמה באופן ישיר מהעד
# ויות השונות. על כן החלטת בית המשפט המחוזי לבטל את ההרשעה בעבירת ההפקרה ובד בבד ל
# הותיר על קנה את ההרשעה בעבירת ההפרעה בדין יסודה. טענותיו של בא-כוח המבקש לענין ח
# ומרת העונש, אף הן אינן מצדיקות את התערבותו של בית-משפט זה. הלכה היא, כי טענות בנ
# וגע לחומרת העונש כשלעצמה, אינן מקימות עילה למתן רשות ערעור בפני בית-משפט זה, אלא
#  בנסיבות של סטייה ניכרת ממדיניות הענישה (ראו רע"פ 1174/97 רפאלי נ\' מדינת ישראל
# (לא פורסם); רע"פ 7201/97 בשירי נ\' היועץ המשפטי לממשלה (לא פורסם)). מקרה זה אינו
#  מקרה חריג, המצדיק סטייה מהלכה זו. העונש שהוטל על המבקש אינו חורג ממתחם הענישה ה
# מקובל בעבירות מהסוג שביצע ונסיבות המקרה אינן מצדיקות התערבות בית-משפט זה (ראה מק
# רים דומים: רע"פ 10694/05 אשר נ\' מדינת ישראל (טרם פורסם); רע"פ בוהדנה נ\' מדינת
# ישראל (טרם פורסם)). אשר-על-כן, הבקשה למתן רשות ערעור נדחית. ניתנה היום, א\' בניס
# ן התשס"ז (20.3.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכה
#  וניסוח. 06107030_H03.doc /צש מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 367, Trimmed Length: 317):
# ['החלטה בתיק רע"פ 1469/06 בבית המשפט העליון רע"פ 1469/06 - ד\' בפני: כבוד השופט
# ס\' ג\'ובראן המבקשת: אושרת בניטה נ ג ד המשיבה: מדינת ישראל בקשה לעיכוב ביצוע גזר
#  דין החלטה הבקשהנדחית. ניתנה היום, כ"ג בתשרי תשס"ז(15.10.06). שו פ ט ___________
# ______________העותק כפוף לשינויי עריכה וניסוח. 06014690_H07.docחכ/מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 11727, Trimmed Length: 1000):
# פט. רשויות התביעה,בית-משפט השלום ובית-המשפט המחוזי עשו את מלאכתם נאמנה ועל-כן, א
# ין לקבוע, כיהמקרה שבפנינו אכן נופל בגדרם של "המקרים החריגים ביותר", בהם יש מקוםל
# מתן סעד של הגנה מן הצדק ולביטול כתב האישום וההליך הפלילי כולו. גם הטענה, כיחוקרי
#  נציבות מס הכנסה ציינו בפני המבקשת, כי ימליצו בחיוב על הטלת כופר, וודאיאינה מגיע
# ה לכדי התחייבות, מצג או החלטה בדבר אי העמדה לדין, המצדיקים סעד קיצונישל ביטול כת
# ב אישום (ראו ישגב נקדימון, הגנה מן הצדק (תשס"ג)229-264 וכן ע"פ 6411/98 נחום מנבר
#  נ\' מדינת ישראל,פ"ד נה(2) 150). מצבה האישי של המבקשת אכן איננו פשוט וישמקום להת
# חשבות בו. יחד עם זאת, מצב זה נלקח בחשבון כבר עם מתן גזר-הדין בבית-משפטהשלום, אשר
#  לכל הדעות איננו מן החמורים. יש גם לקחת בחשבון את האינטרס הציבוריהכללי הנפגע בעב
# ירות מס, על אחת כמה וכמה כאשר הללו מבוצעות על-ידי עורכי-דין,האמורים להוות אות ומ
# ופת לשמירת החוק. סופו של דבר, הבקשה למתן רשות ערעורנדחית בזאת. ניתנה היום, כ"ז ב
# תשרי תשס"ז (19.10.2006). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06019280_H09.doc אתמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2943, Trimmed Length: 1000):
# ג מגדריה של הפרשה המסוימת בה היההמבקש מעורב, ואין היא מגלה שאלה כללית שיש מקום ל
# שוב וללבנה (השוו רע"פ10687/02 הנדימן עשה זאת בעצמך בע"מ נ\' מדינת ישראל, פ"דנז(3
# ) 1, 4; רע"פ 2192/01 פנחסי נ\' מדינת ישראל, תקדין עליון2001(3) 2135; רע"פ 9392/0
# 2 מסארווה נ\' מדינת ישראל,תקדין עליון 2002(3) 166; רע"פ 6012/03 עסל נ\' מדינתישר
# אל (טרם פורסם); רע"פ 6115/03 דדוביץ נ\' מדינתישראל, תקדין עליון 2003(2) 3214)).
# אף בכל הנוגע למידת העונש, לא הראההמבקש עילה לסטייה מן הכלל לפיו אין טענות כנגד ח
# ומרת גזר הדין מצדיקות דיון חוזר,שלישי במספר (השוו רע"פ 149/88 טוביה נ\' היועץ המ
# שפטי לממשלה, תקדיןעליון 88(1) 663; רע"פ 1174/97 רפאלי נ\' מדינתישראל, תקדין עליו
# ן 97(1) 42; רע"פ 4938/98 אח\'ליל נ\' מדינתישראל, תקדין עליון 98(4) 609; רע"פ 965
# 5/02 פלוני נ\' מדינתישראל, תקדין עליון 2002(3) 49; רע"פ 5258/03 פדילה נ\' מדינתי
# שראל, תקדין עליון 2003(2) 3000). על יסוד טעמים אלה, הבקשה נדחית. ניתנה היום, כ"ה
#  בניסן תשס"ו(23.4.2006). ש ו פ ט_________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06029930_O01.doc/שבמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2382, Trimmed Length: 1000):
# קנס, וכן שבית-המשפט יעיין בגיליון הרשעותיו, הכולל לא פחות מ-127 הרשעותקודמות בעב
# ירות תעבורה. משכך נקבע, כי אין לשעות לטענת המבקש לפיה לא היה מקוםלהחמיר עמו מעבר
#  לקנס המוטל בדרך-כלל בגין העבירה בה הורשע, וכי עברו המכבידבעבירות תנועה, כמו גם
# היותו של המבקש אדם הנוהג בדרכים שעות רבות של היום,מצדיקות את העונש שנגזר לו. עתה
#  עותר המבקש כי תינתן לו רשות לערערעל פסק-דינו של בית-המשפט המחוזי, ואת זאת הוא ע
# ושה על יסוד הטענות ששימשו אותובערעורו לפני בית משפט קמא. 5. דין הבקשה להידחות. ה
# לכה היא, כי רשותערעור אינה ניתנת כדבר שבשגרה, ועל העותר לקבלתה להראות כי בקשתו מ
# עלה שאלה כללית,החורגת מגדר עניינו הפרטני. הבקשה שפני – העוסקת בהרשעתו של המבקש ו
# בחומרת העונששנגזר לו – אינה מעלה שאלה מעין זו, ועל כן דינה להדחות. למען הסר ספק
# אוסיף, כיאף לגופו של עניין לא נמצאה לי עילה ליתן רשות ערעור, הואיל ונוכח עברו המ
# כביד שלהמבקש לא גלומה בעונש שהושת עליו חומרה כלשהי. הבקשה נדחית. ניתנה היום, י"א
#  באייר תשס"ו(9.5.2006). ש ו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06037810_O01.doc/שבמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 1806, Trimmed Length: 1000):
# ט המחוזי להשיב את הדיון לבית-משפט השלום. 2. על החלטה זו הגיש המבקש את בקשת רשות
# הערעור המונחת בפני, ובה הוא מלין על החלטתו של בית-המשפט המחוזי שלא לזכותו אלא לה
# שיב את הדיון לערכאה הדיונית. לדידו, החלטה זו גורמת לו עיוות דין, שכן היא מאפשרת
# למשיבה להוסיף ולהביא ראיות נוספות גם לאחר סיום פרשת התביעה. 3. דין הבקשה להידחות
#  באשר היא מוקדמת. בית המשפט המחוזי, מכוח סמכותו לפי סעיף 213(1) לחוק סדר הדין הפ
# לילי [נוסח משולב], התשמ"ב-1982, החליט להשיב את הדיון לערכאה הדיונית, וממילא טרם
# הוכרעה שאלת אחריותו הפלילית של המבקש למעשה שיוחס לו. רק לאחר שהמבקש ימצה את ההלי
# כים העומדים לרשותו מכוח הדין, תיסלל בפניו הדרך לעתור בפני בית משפט זה, ככל שיידר
# ש, להתיר לו להביא את עניינו בפני ערכאה שלישית (השוו רע"פ 3545/06 אורה מושב עובדי
# ם להתיישבות נ\' מדינת ישראל, לא פורסם; רע"פ 3290/03 ספידי ליין יבוא ושיווק מוצרי
#  צריכה בע"מ נ\' מדינת ישראל, לא פורסם). אשר על כן הבקשה נדחית. ניתנה היום, י"ז ב
# סיוון התשס"ז (3.6.07). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 06107380_O05.doc קה מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 4076, Trimmed Length: 1000):
# הידחות גם לעצם העניין. מתקשהאני להתעלם מעברו התעבורתי העשיר של המבקש, אשר מעולם
# לא היה זכאי לקבלת רישיוןנהיגה ואף-על-פי-כן הורשע בעבר ב-6 עבירות שונות של נהיגה
# ללא רישיון. אף העובדהשהמבקש ריצה כבר בעבר עונש מאסר בין כותלי בית הסוהר בגין ביצ
# וע עבירה דומה, לאהרתיעה אותו מלחזור ולנהוג ללא רישיון, תוך שהוא שב ומסכן את חייה
# ם של אחרים ואתחייו שלו עצמו. בצדק ציינה המשיבה, כי המבקש סיגל לו מנהג פסול ומסוכ
# ן לנהוג ברכבמבלי שהונפק לו רישיון נהיגה. נסיבות חייו של המבקש, קשות ככל שיהיו, א
# ינן מהוותצידוק להקל עימו בדין, שעה שהוא הוכיח במעשיו, פעם אחר פעם, כי אין עליו מ
# ורא הדין.בנסיבות אלו, לאור ריבוי העבירות, הישנותן וחומרתן, אין מנוס מהרתעה ממשית
# , בדמותושל מאסר בפועל. אשר-על-כן, הבקשה למתן רשות ערעור נדחית. החלטתי מיום 14.3.
# 06 - בנוגע לעיכוב ביצוע גזר-הדין - מבוטלת. על המבקש להתייצבביום 28.5.06 לא יאוחר
#  מהשעה 10:00 במזכירות בית-המשפט המחוזי בירושלים, לשם תחילתריצוי עונשו. ניתנה היו
# ם, טז\' באייר תשס"ו(14.5.06). ש ו פט________________________העותק כפוף לשינויי ע
# ריכה וניסוח. 06023350_H02.docמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2307, Trimmed Length: 1000):
# שרבמסגרתה טוען המבקש, כי שגה בית-המשפט המחוזי בקביעותיו וכי ראוי היה שבעל הרכב,א
# שר ישב לידו באותה עת, הוא אשר יקבל את הקנס. דין בקשת רשות הערעור להידחות, וזאת מ
# בלילבקש את תגובת המשיבה. עניינו של המבקש כבר נדון בפני שתיערכאות. כידוע, הכלל הנ
# והג הינו, כי הרשות לערעור שני, אינה ניתנת כדבר שבשגרה,אלא מוגבלת למקרים המעוררים
#  שאלה בעלת חשיבות משפטית או ציבורית, החורגת מעניינםהפרטני של הצדדים. כך נקבע בר"
# ע 103/83 חניון חיפהבע"מ נ\' מצת אור (הדר חיפה) בע"מ, פ"ד לו(3) 123 (להלן: חניון
# חיפה).בקשת רשות הערעור איננה מעוררת כל שאלה משפטית עקרונית שכזו והמבקש לא הצביע
# עלעילה המצדיקה דיון "בגלגול שלישי", בהתאם להלכת חניון חיפה. דין הבקשה להידחות גם
#  לגוף העניין. לשוןהמחוקק וכוונתו בתקנה 14 לתקנות התעבורה ברורה ומטרתה להטיל את ה
# אחריות על הרכב,בין השאר לתקינותו, על הנוהג ברכב וזאת בנוסף על בעלי הרכב, על בעל
# הרישיון,ההחזקה או השליטה בו. אשר-על-כן, הבקשה למתן רשות ערעור נדחית. ניתנה היום,
#  ד\' בניסן תשס"ו (2.4.2006). שו פ ט_________________________העותק כפוף לשינויי ע
# ריכה וניסוח. 06027040_H01.docמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 3842, Trimmed Length: 1000):
# ך ביטוי לכל אורך עדותה.לדבריה, היא סלחה למערער, אינה מעוניינת בליבוי המריבה, וכל
#  רצונה בסיום ההליך.חרף גישתה זו, אישרה המתלוננת בדיעבד, כי הדברים שאמרה בהודעתה
# במשטרה, דברי אמתהם, וחזרה על עיקרי הדברים גם בבית המשפט. משכך, אמרתה איננה מהווה
#  אמירה שהתקבלהמכח סעיף 10א ואינם טעונים חיזוק" (עמוד 7 לפסק-הדין). 4. עתה עותר ה
# מבקש ליתן לו רשות לערער, ובפיוטענות זהות לאלה שהשמיע במהלך הדיון בפני בית המשפט
# המחוזי. לכך לא אוכל להיעתר.רשות ערעור יוחדה למקרים חריגים בהם מתעוררת שאלה משפטי
# ת, לה עשויה להיות השלכההחורגת מעניינם של הצדדים המתדיינים. לא כזו היא הבקשה שבפנ
# י, שכל כולה מופניתכנגד ממצאים שבעובדה ומהימנות, בהם, מכוח ההלכה הפסוקה, אין ערכא
# ת ערעור נוהגתלהתערב, ומקל וחומר שכך לא תעשה ערכאת ערעור בגלגול שני. כך או כך, ענ
# יינו שלהמבקש נבחן על-ידי שתי ערכאות, ולא מצאתי כי בפסקי דינן המפורטים והמנומקים
# נפלופגם או שגגה. התוצאה היא כי דינה של הבקשה להדחות, וכךאני עושה. ניתנה היום, ז\
# ' בשבט תשס"ו(5.2.2006). ש ו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06005640_O01.doc/שבמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 4071, Trimmed Length: 1000):
#  לתקופה של שנתיים, במקרה של עבירה של שימוש עצמי שנעברה בפעם שניה, וזאת למעט חריג
#  של נסיבות מיוחדות (ראה גם: ד"כ 12(4), תשנ"ב, עמ\' 904-905). במידה והורשע אדם בפ
# עם הראשונה, הרי שסמכות בית המשפט נותרה על כנה לפסול את רשיונו לתקופה שלא תעלה על
#  חמש שנים, על בסיס סעיף 37א(א). הפרשנות המשפטית שמציע בא-כוח המבקש מוציאה מתכולת
#  סעיף 37א(א) עבירות של שימוש עצמי. יוצא מדבריו, שהתיקון אשר הוסיף את סעיף 37א(א1
# ), בא להגביל את ידי בתי-המשפט בהענשה על עבירות סמים. פרשנות זו אינה סבירה. היא ס
# ותרת את תכלית המחוקק להיאבק בנגע הסמים. כמו כן היא סותרת את דברי ההסבר שליוו את
# התיקון ואשר הדגישו את אלמנט הגברת ההרתעה (הצ"ח, 2066,עמ\' 272; ד"כ 12(4), תשנ"ב,
#  עמ\' 904). גם ההגיון הבריא אינו מתיישב עם הפרשנות שמציע בא-כוח המבקש: האם סבור
# המבקש שהחוק מאפשר לגזור שלוש שנות מאסר בגין עבירה של אחזקת סמים לשימוש עצמי, אך
# לא מאפשר שלילת רשיון? אשר-על-כן, הבקשה למתן רשות ערעור נדחית. ניתנה היום, י"ט בש
# בט התשס"ז (7.2.2006). ש ו פ ט _________________________ העותק כפוף לשינויי עריכה
#  וניסוח. 06096320_H02.doc /צש מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 4725, Trimmed Length: 1000):
# הסתמך בית-המשפט עלהעובדה, כי המבקש לא טען בעדותו, כי הופתע מהאירוע או כי אינו זו
# כר אותו. וכך קבעבית-המשפט לתעבורה: "לאחר שמיעת הראיות לעניין ההתיישנות, אני קובע
# ת, כי הודע לנאשםדבר היותו חשוד בביצוע עבירת תעבורה. הנאשם עצמו מאשר קיומו של דין
#  ודברים עםהשוטר. מאסר מסירת פרטיו לשוטר וזוכר את המקרה לפרטיו." טענות המבקש מבוס
# סות על ממצאים עובדתייםשנקבעו על-ידי הערכאה הדיונית. ברם, כידוע, הלכה היא, כי קבי
# עה עובדתית שנקבעהבערכאה דיונית לא תתבטל על נקלה בערכאת הערעור, אפילו זו האחרונה
# הייתה פוסקת אחרתלו שמעה בעצמה את העדים, כל עוד יש לקביעת עובדה שכזאת יסוד ושורש
# בחומר הראיות.דעתו של השופט אשר ראה ושמע את העדים והתרשם התרשמות ישירה ובלתי אמצע
# יתממהימנותם, היא הקובעת (ראו ע"א 5118/92 חברת אלטריפי נ\' סלאיימה, פ"ד נ(5) 407)
# . טענותיו של המבקשנדונו הן על-ידי הערכאה הדיונית והן על-ידי ערכאת הערעור ולא מצא
# תי מקום לקיום דיוןנוסף בענין. סוף דבר, הבקשה למתן רשות ערעור נדחית. ניתנה היום,
# י"ג באלול תשס"ו(6.9.06). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06030180_H03.doc הגמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 5985, Trimmed Length: 1000):
# שלבמעשיו. יעידו על כך ההמלצות והתעודות אשר צורפו לבקשה. התרשמתי אף ממכתבו של מרא
# וקלנדר. יחד עם זאת, יש להתחשב גם באינטרסהציבורי ובהרתעה הציבורית מפני מעשי אלימו
# ת כלפי עובדי ציבור בכלל, ובזמן מילויתפקידם בפרט. האלימות איננה חלק לגיטימי מתרבו
# ת הדיון והמחאה ויש לעצור כל גילוישלה בחומרה. בנסיבות המקרה, לא שוכנעתי, כי אין י
# חס סביר בין ההשלכות שעלולות לבואמהרשעת המבקש לבין חומרת עבירת האלימות אותה עבר.
# כן נראה בעיני, כי יש חשיבות באי-עשייתןשל החלטות בתי-המשפט פלסתר. אין זה מתקבל על
#  הדעת, כי בית-המשפט ילך לקראת נאשםפעם אחר פעם וייענה בזלזול מצידו. אין טיבה של א
# י-הבנה להימשך במשך חודשים רביםומכתבים רבים ונימוק זה איננו מצדיק את אי-הופעתו של
#  המבקש באופן חוזר ונשנה.בהתעלמות זו של המבקש, יש משום בזבוז משאבי בית-המשפט ושיר
# ות המבחן, ויש בהם משוםהצהרה מעשית, כי המבקש לא הפנים את הלקח של לקיחת אחריות על
# מעשיו וכיבוד ערכיהחברה. אשר-על-כן, הבקשה למתן רשות ערעור נדחית. ניתנה היום, כ"ז
# באלול תשס"ו (20.9.2006). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06046530_H03.doc אתמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2844, Trimmed Length: 1000):
# ות לערער,ובבקשתו מעורר הוא השגות כנגד מסקנות עובדתיות וממצאי מהימנות. נטען, כי ה
# מתלוננתהייתה זו שיצרה קשר עם המבקש, ולא להיפך, וכי לא היה ראוי להעניק לגרסאותיה
# אמון.כן נטען, כי הכרעת-הדין בעניינו של המבקש אינה מנומקת דייה, ואינה כוללת התייח
# סותלשאלת מהימנותם של עדי התביעה. לחלופין, נטען כי ראוי להקל בעונשו של המבקשולהימ
# נע מהפעלתו של עונש המאסר על תנאי. 5. דין הבקשה להידחות. הלכה היא כי רשותערעור ני
# תנת במשורה באשר היא מיועדת למקרים חריגים המעוררים שאלות משפטיות כלליות,החורגות מ
# עניינם של הצדדים המתדיינים (ראו ר"ע 103/82 חניון חיפה בע"מ נ\' מצת אור (הדר חיפה
# ) בע"מ פ"דלו(3), 123). הבקשה שבפני אינה מגלה עילה מסוג זה, אדרבא, השגותיו של המב
# קש כנגדהרשעתו מופנות כולן כנגד ממצאים שבעובדה, שכאמור, ערכאת ערעור, ומקל וחומר ע
# רכאתערעור שנייה, אינן נוהגות להתערב בהם. כך או כך, עניינו של המבקש נבחן בקפידה ב
# ידישתי ערכאות, ולא מצאתי מקום לשוב וללבנו בשלישית. הבקשה נדחית. ניתנה היום, כ"ז
# בתמוז התשס"ו(23.7.2006). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06058910_O01.doc גקמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 5147, Trimmed Length: 1000):
# יון נהיגה, אשר פקע בחודש פברואר1989, בזמן פסילה וללא ביטוח. התנהגותו זו של המבקש
#  - בצירוף עברו התעבורתי המכביד,הכולל 45 הרשעות קודמות ועברו הפלילי וכן העובדה, כ
# י בעת ביצוע המעשים היה תלויועומד כנגדו מאסר על תנאי, שכבר הוארך פעם אחת – מצביעה
#  על דפוס של זלזול בהחלטותבתי המשפט מצידו ועל היעדר מורא מפני רשויות אכיפת החוק.
# אני סבור, כי לאור חומרתהעבירות בהן הורשע המבקש, ריבוין, נסיבות ביצוען, העובדה, כ
# י באותה העת היה קייםמאסר על תנאי חב הפעלה כנגד המבקש וכן לאור עברו התעבורתי המכב
# יד של המבקש, איןמקום להתערב בגזר-הדין של בית-משפט השלום לתעבורה. יתרה מכך, בית-מ
# שפט השלום לתעבורה נתןדעתו לנסיבותיו האישיות של המבקש, שקל ואיזן אותן במכלול השיק
# ולים עובר לגזירתעונשו. אף בית-המשפט המחוזי נתן דעתו לנסיבותיו האישיות של המבקש,
# אולם לא מצאמקום להתערב בגזר-הדין של בית-משפט השלום לתעבורה. בנסיבות אלה, אף אני,
#  לא מצאתימקום להתערב בגזר-הדין. אשר-על-כן, בקשת רשות הערעור נדחית. ניתנה היום, כ
# "א בתמוז תשס"ו(17.7.06). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06035310_H04.doc דפמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2728, Trimmed Length: 1000):
#  בקשת רשות הערעור איננה מעוררת כל שאלה משפטיתעקרונית שכזו והמבקש לא הצביע על כל
# עילה המצדיקה דיון "בגלגול שלישי",בהתאם להלכת ר"ע 103/82 חניון חיפה בע"מ נ\' מצת
# אור (הדר חיפה)בע"מ, פ"ד לו(3) 123. מסיבה זו בלבד, דין הבקשה להידחות. זאת ועוד, ה
# לכה היא, כי טענות בנוגעלחומרת העונש כשלעצמה, אינן מקימות עילה למתן רשות ערעור בפ
# ני בית-משפט זה, אלאבנסיבות של סטייה ניכרת ממדיניות הענישה (ראו רע"פ 1174/97 עזרא
#  רפאלינ\' מדינת ישראל (לא פורסם); רע"פ 7201/97 דב בשירי נ\' היועץהמשפטי לממשלה (
# לא פורסם)). מעבר לדרוש יוער, כי דין הבקשה להידחותגם לעצם העניין. משלא ערער המבקש
#  על הכרעת-דינו בפני בית-המשפט המחוזי, הרישטענותיו כנגד השוטרים שבאו לעצרו אינן מ
# ן העניין. גם העונש שנגזר על המבקש אינוחורג מהענישה המקובלת בעבירה בה הורשע, בפרט
#  לאור עברו הפלילי המכביד, הכולל גםעבירות דומות כנגד עובדי ציבור. אשר-על-כן, הבקש
# ה למתן רשות ערעור נדחיתוממילא מתייתרת הבקשה לעיכוב ביצוע העונש. ניתנה היום, כ"ט
# בתמוז תשס"ו(25.7.2006). ש ו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06059790_H02.doc דממרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 4887, Trimmed Length: 1000):
# שים כלפיו, ורק באופן מקרי לא הסתכמה פרשת עבירות אלהבשלילת סכומי כסף ניכרים ביותר
#  מהמעביד. עבירותזיופי המסמכים ושיבוש הליכי המשפט הינן חמורות ביותר כשלעצמן, ומצב
# יעות על נועזות בהצגתמצגי כזב אף בפני הרשות השיפוטית. מישנה חומרה נלווית לעובדה כ
# י גם המערך הטיפולישנערך לסייע למערער במהלך ההליכים נפל קרבן למעללי שקריו, והרושם
#  המצטייר הוא כי ההליךהשיקומי, במידה שהוא קיים, אינו מהווה מוצא בר-סיכוי נכון לעת
#  זו. על רקעמצב דברים זה, גזר הדין שנגזר על המערער בבית משפט השלום סוטה סטייה ניכ
# רתממדיניות הענישה הראויה. גזר הדין בערעור אמנם החמיר עם המערער החמרה משמעותית, א
# ךלא סטה מפער הענישה הסביר בין הערכאה הדיונית לערכאת הערעור, על רקע כלל נסיבותהענ
# ין והעונש שהיה ראוי לגזור על המערער. בנסיבותאלה, אנו דוחים את הערעור, ומותירים א
# ת פסק דינו של בית המשפט המחוזי בעינו. עלהמבקש להתייצב לריצוי עונשו ביום 15.10.06
#  עד שעה 10:00 במזכירות בית המשפט המחוזיבתל-אביב. ניתןהיום, י"א בתשרי תשס"ז (03.1
# 0.06). ש ו פ טת ש ו פ טת ש ו פ ט _________________________העותק כפוף לשינויי ערי
# כה וניסוח. 06006950_R04.doc יטמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 6993, Trimmed Length: 1000):
# חות. שכן, כידוע, אין בחומרת העונש כשלעצמה כדי ליתן רשות ערעור בפני בית-משפט זה,
# אלא בהתקיים נסיבות חריגות של סטייה ניכרת ממדיניות הענישה (ראו רע"פ 7201/97 דב בש
# ירי נ\' מדינת ישראל (לא פורסם); כך, למשל, נקבע ברע"פ 1174/97 עזרא רפאלי נ\' מדינ
# ת ישראל (לא פורסם): "בית משפט זה אינו נוהג ליתן רשות ערעור שעה שהערעור המבוקש עו
# סק אך ורק בחומרת העונש שנגזר: \'הלכה היא מימים ימימה, כי \'על חומרת העונש אין נו
# הגים לתת רשות לערער בכלל כי בעניין עונש מספיקות שתי ערכאות די והותר\'... רשות כז
# את ניתנת רק במקרים חריגים ומיוחדים והמקרה דנן אינו כזה\'" (ראו גם רע"פ 1459/91 ט
# ולדנו נ\' מדינת ישראל (לא פורסם); רע"פ 2092/04 קשקוש נ\' מדינת ישראל (לא פורסם))
# . במקרה דנן, יש לציין, כי בית-משפט השלום נתן דעתו בגזר-הדין לנסיבותיו האישיות של
#  המבקש ונראה, כי העונש שהוטל על המבקש אינו חמור כלל וכלל, זאת במיוחד נוכח היותו
# עובד ציבור בעת ביצוע העבירה. אשר-על-כן, בקשת רשות הערעור נדחית. ניתנה היום, י"ט
# בטבת תשס"ז (9.1.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 06091170_H02.doc דפ מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 4923, Trimmed Length: 1000):
# ולמו באתר הבנייה בשנת 2002 ובשנת 2004 ומהן עולה כי בשנת 2002 המבנה טרם הוקם, בעו
# ד שבשנת 2004 רואים את המבנה בצילומים. מכאן, עולה בבירור שהמבנה אכן נבנה בשנת 200
# 3 וכי גרסתו של המבקש, לפיה בנה את המבנה בשנת 1998 איננה נכונה. בית המשפט המחוזי
# אישר את קביעתו של בית משפט השלום. זאת ועוד. אין להקל ראש בעבירת הבנייה בה הורשע
# המבקש, והעונש שנפסק בגינה הולם, כך לידידי, את חומרתה. על העונש שנגזר בגין עבירות
#  נגד חוקי התכנון ובניה לשקף את חומרת המעשים והפגיעה בשלטון החוק ולשמש גורם הרתעה
#  עבור ונגד עבריינים פוטנציאלים, במטרה להפוך את ביצוע העבירות מן הסוג האמור לבלתי
#  כדאיות מבחינה כלכלית. כבר נפסק בעבר, כי בתי-המשפט מצווים לתת יד למאבק בעבירות ה
# חמורות בתחום התכנון והבנייה, שהפכו לחזון נפרץ בימינו (ראו למשל רע"פ 2809/05 טסה
# נ\' מדינת ישראל (לא פורסם) והאסמכתאות שם). אשר-על-כן, דין בקשת הערעור להידחות. ה
# חלטתי מיום 31.12.06 בדבר עיכוב ביצוע צו ההריסה מבוטלת בזאת. ניתנה היום, י"א באיי
# ר התשס"ז (29.4.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכה
#  וניסוח. 06106360_H03.doc /צש מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 5754, Trimmed Length: 1000):
# שנקבעועל-ידי הערכאות הקודמות. כידוע, הלכה היא, כי בית-משפט בשבתו כערכאת ערעור אי
# ננונוטה להתערב בממצאים עובדתיים אותם קבע בית-משפט של הערכאה הדיונית אשר שמעה אתה
# עדויות, התרשמה מהן ובחנה אותן, אלא במקרים חריגים (ראו ע"פ 11/99 שוורץ נ\' מדינת
# ישראל, פ"ד נד(3) 769, 780; ע"פ190/82 מרקוס נ\' מדינת ישראל,פ"ד לז(1) 225, 234).
# המקרה שבפנינו אינו אחד מאותם מקריםחריגים המצדיקים התערבות של ערכאת הערעור בממצאי
#  המהימנות של הערכאה הדיונית.בית-משפט השלום שמע עדויות של עדים מומחים אשר התייחסו
#  לשאלה האם אדם בעל ניסיוןיכול להעריך מהירות של כלי שיט בים כאשר מדובר בהפרשים מש
# מעותיים. משנפסק, כיהתשובה לשאלה זו הינה חיובית, הגיע בית-משפט השלום למסקנה, כי מ
# קובלת עליו עדותםשל השוטרים, שהינם בעלי ניסיון והכשרה מתאימה, לפיה המבקש השיט את
# כלי-השיט שלו במהירותהעולה על חמישה קשרים. בנסיבות אלו, לא מצאתי מקום להתערב בפסק
# -דינו שלבית-המשפט המחוזי. אשר-על-כן, דין בקשת רשות הערעור להדחות. ניתנה היום, ג\
# ' בטבת תשס"ז(24.12.06). ש ו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06085160_H02.doc תומרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2269, Trimmed Length: 1000):
# הופנו לכך שהוא נשלח לשאת בעונש מאסר,בעוד שעל המתלונן ואחיו הוטלו קנס ומאסר על תנ
# אי בלבד. בית-המשפט המחוזי (סגןהנשיא ז\' המר והשופטים י\' שיצר וי\' שבח) דחה את ה
# ערעור, תוך שהפנה לעברו המכביד שלהמבקש, לאלימות הקשה שהפעיל באירוע זה, ולחומרת הפ
# גיעה שנגרמה למתלונן. מכאן הבקשהשבפני, בה שב המבקש על השגותיו לעניין חומרת העונש
# שנגזר לו, ועותר כי תינתן לובשל כך רשות לערער. 4. דין הבקשה להידחות. עניינו של המ
# בקש אינומעלה שאלה משפטית כללית בעלת חשיבות ציבורית כלשהי, ובשל כך, אין הוא מצדיק
#  אתליבונו בפני ערכאה שלישית (ראו רע"פ 10231/03 ציון קורןנ\' מדינת ישראל, פ"ד נח
# (1) 646). השגותיו שלהמבקש מופנות כנגד חומרת העונש בלבד, וזו, כשלעצמה, אינה מהווה
#  עילה למתן רשותערעור. נוכח האלימות הקשה בה נקט המבקש כלפי המתלונן, והעובדה כי אי
# ן זו הפעםהראשונה בה חטא בפלילים, איני מוצא כי עניינו בא בגדרם של החריגים להלכה ז
# ו. אשר על כן, הבקשה נדחית, ועימה גם הבקשהלעיכוב ביצועו של העונש. ניתנההיום, כ"א
# בחשוון תשס"ז (12.11.06). שו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06092720_O01.doc אזמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2211, Trimmed Length: 1000):
# נדונה במעמדהצדדים ביום ט"ז בכסלו התשס"ז (7.12.06), ונדחתה. עתה עותר המבקש ליתןלו
#  רשות לערער, הואיל ולהשקפתו מידת הצדק מחייבת זאת. אין בידי להיעתר לבקשה. ההליכים
#  בעניינו שלהמבקש החלו בחודש יוני 2002, כאשר הוגש נגדו כתב האישום הראשון (ת.פ. 56
# 15/02),ונמשכו בשנת 2004 בעת שהוגש כתב האישום השני (ת.פ. 918/04). העולה מכך הוא,
# כי עדלהחלטתו האחרונה של בית המשפט המחוזי (בחודש דצמבר 2006), עמדו לרשות המבקש אר
# בעוחצי שנים להסיר את מחדליו כלפי שלטונות מס ערך מוסף ולשלם את חובו. את מחדליובתח
# ום המס השלימו המבקש ובא-כוחו בהיעדרויות חוזרות מבית המשפט, ועל כן לא ניצב בפנימי
#  שלא ניתן לו יומו בבית המשפט, אלא דווקא מי שניתנו לו אין ספור הזדמנויות להסיראת
# מחדליו, ומטעמים השמורים עמו הוא נמנע מלעשות כן. כך או כך, בית המשפט המחוזיבהחלטה
#  נושא הבקשה לרשות לערער, הבהיר כי נתן את דעתו גם להשגות המבקש כנגדגזר-הדין, ומקו
# בלת עלי השקפתו כי לא היה מקום להקל בעונש. אשר על כן, הבקשה נדחית. ניתנה היום, י\
# ' בטבת תשס"ז(31.12.06). ש ו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06101740_O01.doc אזמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2542, Trimmed Length: 1000):
# הלכה היא כי רשותערעור ניתנת במשורה, ומיועדת היא לאותם מקרים חריגים המעוררים סוגי
# ות משפטיותכלליות, בעלות השפעה החורגת מעניינם של הצדדים המתדיינים. לא כזו היא הבק
# שה שבפני,הנסבה על חומרת העונש, וככזו היא אינה מקימה, כשלעצמה, עילה למתן רשות ערע
# ...
# Trimmed Text (Original Length: 4278, Trimmed Length: 1000):
# ת ממדיניות הענישה (ראו רע"פ 1174/97 עזרא רפאלי נ\' מדינת ישראל (לא פורסם)(1997);
#  רע"פ 7201/97 דב בשירי נ\' היועץ המשפטי לממשלה (לא פורסם)(1997)). במקרה שבפנינו
# לא מצאתי כל חריגה שכזו. מסיבה זו בלבד, דין הבקשה להידחות. מעבר לדרוש יוער, כי די
# ן הבקשה להידחות גם לגופו של עניין. העונש שהוטל על המבקש הולם את מדיניות הענישה ה
# מקובלת בעבירות מסוג זה ואת חומרת העבירות בהן הורשע, כאשר נסיבותיו האישיות היו יד
# ועות לערכאות הקודמות אשר גזרו את דינו. המבקש, אשר עבר עבירה של נהיגה בזמן פסילה,
#  בשעה שהוא מבצע עבודות שרות שהוטלו עליו בגין ביצוע אותה עבירה ממש, הוכיח במעשיו
# כי לא ניתן עוד להמשיך ולהקל בעונשו וכי אין מנוס מפני שליחתו למאסר משמעותי מאחורי
#  סורג ובריח. אשר על כן, הבקשה למתן רשות ערעור נדחית. החלטתי מיום 18.7.2007 בדבר
# עיכוב ביצוע עונש המאסר מתבטלת בזאת. המבקש יתייצב במזכירות בית המשפט המחוזי בתל-א
# ביב ביום 7.10.07 לא יאוחר משעה 10:00, לשם תחילת ריצוי עונשו. ניתנה היום, כ"א באל
# ול התשס"ז (4.9.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכה
#  וניסוח. 07062060_H03.doc /צש מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2871, Trimmed Length: 1000):
# בעניינו של המבקש, שאלה כזו אינה מתעוררת. חרף הכסות המשפטית בהן עטה את טענותיו, ב
# סופו של יום מדובר בסוגיה עובדתית – מעמדו של הנוסע שהיה עמו – אשר הוכרעה על פי רא
# יות בהן מצא בית משפט השלום ליתן אמון (התעודה ת/1, ועדותם של שי ברק והנוסע שהסיע
# המבקש). מסקנותיה של הערכאה הדיונית נבחנו פעם נוספת בידי ערכאת הערעור, ובכך די. ג
# ם בטענה לפיה נפל פגם בגביית עדותו המוקדמת של הנוסע (העדר תיעוד חזותי), לא מצאתי
# ממש. סעיף 120א אליו הפנה המבקש נוסף רק בשנת התשס"ד, ונקבע כי תחילתו ביום כ"א בטב
# ת התשס"ה (2 בינואר 2005). העולה מכך הוא כי תיקון זה אינו יכול לחול על גבייתה של
# עדות מוקדמת שכתב האישום בגינה הוגש בשנת 2004. גם בהשגות לעניין העונש לא מצאתי ממ
# ש. כידוע, ההלכה הנוהגת היא כי חומרת העונש כשלעצמה אינה מקימה, על דרך הכלל, עילה
# למתן רשות לערער (רע"פ 10231/03 קורן נ\' מדינת ישראל, פ"ד נח(1) 646), ולא ראיתי מ
# קום לחרוג מהלכה זו בעניינו של המבקש. אשר על כן, הבקשה נדחית. ניתנה היום, י"א בסי
# וון התשס"ז (28.05.07). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 07045090_O01.doc אז מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 642, Trimmed Length: 592):
# ['החלטה בתיק רע"פ 6436/07 בבית המשפט העליון רע"פ 6436/07 בפני: כבוד השופט א\' א\
# ' לוי המבקש: בנימין בן נתן נגד המשיבה: מדינת ישראל בקשה לעיון חוזר בבקשה לעיכוב
# ביצוע בשם המבקש: עו"ד אליהו שטרית החלטה ביום ט"ו באב התשס"ז (30.7.07) נדחתה בקשת
# ו של המבקש ליתן לו רשות ערעור על פסק-דינו של בית-המשפט המחוזי בתל-אביב, בע"פ 712
# 25/05. בנסיבות אלו אין מקום לעכב את ביצוע העונש, ואם סבור המבקש כי יש בידו טעם ר
# אוי לכך, יביאנו בפני הערכאה שגזרה את הדין. הבקשה נדחית. ניתנה היום, ט"ז באב התשס
# "ז (31.07.07). ש ו פ ט _________________________ העותק כפוף לשינויי עריכה וניסוח
# . 07064360_O03.doc אז מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 5958, Trimmed Length: 1000):
# פ"ד נח(6) 625, בעמ\' 631-632: "כידוע, אין דרכה של ערכאת הערעור להתערב במימצאים ע
# ובדתיים שקבעה הערכאה הדיונית, וקל וחומר במימצאי מהימנות, אלא במקרים חריגים ונדיר
# ים, ורק אם הגירסה העובדתית שהתקבלה על-ידי הערכאה הדיונית אינה מתקבלת על הדעת". ו
# בהמשך – "תפקידה של ערכאת הערעור אינו לבחון מחדש את אשמתו של הנאשם, את צדקתו או א
# ת רשעתו; תפקידה הוא להעביר תחת שבט ביקורתה את פסק-הדין של הערכאה הדיונית ולבחון
# אם "כשר" הוא או "פסול", ואם נפל בו פגם היורד לשורשו של עניין. אם לא נמצא פגם כזה
# , אל לה לערכאת הערעור להתערב בו, אפילו סבורה היא כי התוצאה שאליה הייתה מגיעה לו
# ישבה כערכאה דיונית, יכול שהייתה אחרת". במקרה שלפנינו, הכרעת הדין של בית-משפט השל
# ום מבוססת בעיקרה על ממצאים עובדתיים וממצאי מהימנות. כך למשל אימץ בית-משפט השלום
# את גרסת המתלוננת במלואה והעדיפה על פני גרסת המבקשת. בנסיבות אלה, לא מצאתי כל עיל
# ה להתערבותו של בית-משפט זה. אשר-על-כן, בקשת רשות הערעור נדחית. ניתנה היום, ב\' ב
# אדר תשס"ז (20.2.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 07009550_H03.doc הג מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 1478, Trimmed Length: 1000):
# של"ז-1977, בכך שנכנס למקווה ללא רשות. בעקבות הרשעתו, ומתוך כוונה לאזן בין נסיבות
# יו האישיות הקשות של המבקש, אשר הינו מחוסר-בית, לבין עברו הפלילי המכביד, נגזרו לו
#  שני חודשי מאסר, ועשרה חודשים נוספים על-תנאי, 2. המבקש ערער לפני בית-המשפט המחוז
# י בירושלים כנגד חומרת העונש, וטען כי יש להקל בו משום נסיבותיו האישיות הקשות. עוד
#  נטען, כי הוא נכנס למקווה מתוך כוונה לטבול בו. בית-המשפט המחוזי לא ראה לקבל את ט
# ענותיו, ודחה את הערעור. 3. עתה עותר המבקש ליתן לו רשות לערער, ובפיו אותם נימוקים
#  אשר שימשוהו בפני בית-המשפט המחוזי. 4. דין הבקשה להידחות. ככלל, חומרת העונש לבדה
#  אינה מקימה עילה לדיון בפני ערכאת ערעור שנייה (רע"פ 10231/03 קורן נ\' מדינת ישרא
# ל, פ"ד נח(1) 646 (2003)), ואף שלכלל זה נקבעו חריגים, לא מצאתי כי עניינו של המבקש
#  נמנה עליהם. אכן, מצבו האישי של המבקש – עגום הוא, אך אין בכך הצדקה לעובדה שהוא ש
# ב ומבצע עבירות פליליות חדשות לבקרים. נוכח האמור, הבקשה נדחית. ניתנה היום, ט"ו בא
# לול התשס"ז (29.08.07). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 07070730_O02.doc אז מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 551, Trimmed Length: 501):
# ['החלטה בתיק רע"פ 896/07 בבית המשפט העליון רע"פ 896/07 - ד\' בפני: כבוד השופט ס\
# ' ג\'ובראן המבקש: פבל סמירנוב נ ג ד המשיבה: מדינת ישראל בקשה בהסכמה לעיכוב ביצוע
#  בשם המבקש: עו"ד רותעזריאלנטבשם המשיבה: עו"ד אלעדפירסקי החלטה בהסכמתבא-כוח המשיב
# ה, אני מחליט בזה כי על המבקש להתייצב ביום 10.2.08 לא יאוחר משעה09:00 במזכירות בי
# ת המשפט המחוזי בבאר-שבע לשם תחילת ריצוי עונשו. ניתנה היום, כ"ט בטבת התשס"ח(7.1.2
# 008). ש ו פ ט _________________________העותק כפוף לשינויי עריכה וניסוח. 07008960
# _H06.docהגמרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 469, Trimmed Length: 419):
# ['החלטה בתיק רע"פ 5721/07 בבית המשפט העליון רע"פ 5721/07 - א\' בפני: כבוד השופט
# ס\' ג\'ובראן המבקש: ז\'ק פרץ נגד המשיבה: מדינת ישראל בקשה לעיכוב ביצוע עונש מאסר
#  החלטה לאחר עיון בבקשה ובתגובת המשיבה מהיום, ולאחר ששקלתי את הענין, הגעתי למסקנה
#  כי אין מקום להעתר לבקשה והיא נדחית בזה. ניתנה היום, ב\' בכסלו התשס"ח (12.11.07)
# . ש ו פ ט _________________________ העותק כפוף לשינויי עריכה וניסוח. 07057210_H0
# 3.doc הג מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 3092, Trimmed Length: 1000):
# בית-המשפט לתעבורה לא גזר לו מספר עונשים שונים, ענין בו עוסק סעיף 45(א) הנ"ל, כי
# אם עונש יחיד וכולל, אשר לגביו יפים דברים שכתבה השופטת ד\' ביניש בפרשה אחרת: "עונ
# ש מאסר כולל, כשמו כן הוא. אין הוא ניתן לחלוקה נפרדת על-פי כל אחת מהעבירות בהן הו
# רשע הנאשם. התקרה של עונש כולל נקבעת על פי צירוף כל תקופות העונש המירבי שנקבע לכל
#  אחת מהעבירות שבביצוען הורשע הנאשם. עד לגובה התקרה האמורה, מוסמך בית-המשפט לגזור
#  עונש מאסר כולל, ורשאי הוא להורות כי חלקו או כולו יהיה על-תנאי" (רע"פ 5798/00 רי
# זי נ\' מדינת ישראל, פ"ד נה(3) 1, 12. ההדגשות הוספו). אמור אפוא, כי עונש המאסר הכ
# ולל שנגזר למבקש, לרבות זה שעל-תנאי, מצוי גם מצוי בגדרה של תקרת הענישה האפשרית במ
# קרה דנן. זו מתקבלת מצירוף תקופות המאסר המרביות שניתן להטיל בגין כל אחת מהעבירות
# בנפרד, והיא ארוכה על-כן במידה ניכרת מן העונש שנגזר. בהטילו עונש זה לא חרג בית-המ
# שפט לתעבורה כלל ועיקר מגבולות סמכותו. נוכח האמור, הבקשה נדחית. ניתנה היום, ז\' ב
# אדר התשס"ז (25.02.07). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 07014680_O01.doc אז מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 6075, Trimmed Length: 1000):
# אופק יגבר משקלו של האינטרס הציבורי הכולל בראש ובראשונה את עקרון אכיפת החוק (רע"פ
#  3146/07 ג\'דיר נ\' מדינת ישראל- הועדה המחוזית לתכנון ובניה (טרם פורסם)). במקרה
# דנן קבע בית המשפט המחוזי כי על אף האורכות הרבות שניתנו למבקשים, טרם הצליחו להשיג
#  את הרשיון המיוחל והשגתו בפועל תצריך תקופת זמן נוספת אשר סופה אינו ידוע. על כן ס
# בור אני כי לא נפל פגם בהחלטת בית המשפט המחוזי. אוסיף ואעיר כי עם תום הערעור בבית
#  המשפט המחוזי ודחיית הבקשה בפנינו, נפתחה שוב בפני המבקשים הדרך לבית משפט השלום ב
# הגשת בקשה להארכת מועד ביצוע צו ההריסה לפי סעיף 207 (רע"פ 538/00 שושתרי נ\' מדינת
#  ישראל (לא פורסם)) זאת, כמובן בהנחה שאכן חלו שינויים משמעותיים בנסיבות. אשר על כ
# ן, דין בקשת רשות הערעור להדחות. מאחר והמועד לביצוע צו ההריסה חל בימים הקרובים, ו
# על מנת לאפשר למבקשים זמן אם יחפצו בכך, להגיש בקשה להארכת מועד לפי סעיף 207 בפני
# בית משפט השלום, אני מאריך את עיכוב הביצוע של הצו עד ליום 3.8.07. ניתן היום, י"ז
# בתמוז התשס"ה (3.7.07). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 07056070_H02.doc הג מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 4024, Trimmed Length: 1000):
# תונים הנמסרים להם בידי לקוחותיהם; בדבר היחס בין מה שהוא, לכל היותר, רשלנות בעבוד
# תו של עמיל מכס לבין ייחוסה של מודעות פלילית למעשיו; ובדבר הצידוק שבהטלתו של עונש
#  כבד מקום בו חלפו שנים ארוכות מן המועד בו בוצעו המעשים נושא האישום. 5. טענות אלו
# , מראשיתן ועד סופן, הנן טענות פרטניות, שדבר בהן אינו חורג מעובדותיה המסוימות של
# הפרשה הנדונה. ככאלו, לא יוכל ערעור שני לשמש מסגרת מתאימה לבירורן. בית-משפט זה, ב
# שבתו כערכאה שלישית, לא ישוב, ככלל, ויידרש לממצאי עובדה ומהימנות שנקבעו על יסוד ה
# תרשמותה הבלתי-אמצעית של הערכאה הדיונית מחומר הראיות, ואושרו לאחר בדיקה נוספת ביד
# י ערכאת הערעור. כך הוא גם באשר להתערבות במידת העונש שנגזר, שלא תיעשה אלא במקרים
# מיוחדים בהם ברי, כי עונש זה חורג במידה שלא ניתן להשלים עמה מן הראוי. היות ולא מצ
# אתי בבקשה כל טענה, המשתרעת אל מעבר לגדרות אלו, לא ראיתי מה עילה היא להתרתו של ער
# עור שני. מסקנתי היא, אפוא, כי דין הבקשה להידחות, וכך אני עושה. ניתנה היום, ט\' ב
# אדר התשס"ז (27.02.07). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 07017320_O01.doc אז מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 5412, Trimmed Length: 1000):
# עניינים מקומיים, לפיה לא עלה בידם של המבקשים להוכיח כי הם פעלו על-פי הסכמתן המפו
# רשת של רשויות התכנון. לבסוף אעיר, כי לא נעלמה מעיניי הרגישות הרבה הכרוכה בהריסת
# מבנה המשמש כבית כנסת. אלא, שמטבע הדברים בית משפט אינו יכול להשלים עם התופעה הפסו
# לה של בנייה שלא כדין, הנעשית תוך קביעת עובדות בשטח והפרה בוטה של חוקי התכנון. תו
# פעה, אשר לדאבוננו הרב הפכה לרעה חולה במחוזותינו. משום כך, עמד בית משפט זה לא אחת
#  על חשיבות ביצועו של צו ההריסה המינהלי במועד, כאמצעי יעיל למיגור תופעת הבנייה הב
# לתי חוקית. בנסיבות אלו, איני רואה מקום להתערבות בהחלטותיהן של הערכאות שקדמו לי.
# למבקשים עומדת כמובן האפשרות לקדם הליך בניית בית כנסת חדש במקום בדרכים המקובלות ו
# בסיוע ראשי היישוב. בקשת רשות הערעור נדחית איפוא. בנסיבות אלו, ממילא מתייתר הצורך
#  לדון בבקשה לעיכוב ביצוע צו ההריסה המינהלי. החלטתה של כבוד השופטת א\' חיות מיום
# 1.4.07, באשר לעיכוב ביצועו של צו ההריסה המינהלי מבוטלת בזו. ניתנה היום, ד\' באיי
# ר התשס"ז (22.4.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכה
#  וניסוח. 07030760_H03.doc /צש מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 4761, Trimmed Length: 1000):
# עילה אחרת אשר תצדיק דיון "בגלגול שלישי", בהתאם להלכת ר"ע 103/82 חניון חיפה בע"מ
# נ\' מצת אור (הדר חיפה) בע"מ, פ"ד לו(3) 123 (1982). יתרה מכך, הלכה היא, כי טענות
# בנוגע לחומרת העונש כשלעצמה, אינן מקימות עילה למתן רשות ערעור בפני בית-משפט זה, א
# לא בנסיבות של סטייה ניכרת ממדיניות הענישה (ראו רע"פ 1174/97 עזרא רפאלי נ\' מדינת
#  ישראל (לא פורסם)(1997); רע"פ 7201/97 דב בשירי נ\' היועץ המשפטי לממשלה (לא פורסם
# )(1997)). מסיבות אלו בלבד, דין הבקשה להידחות. מעבר לדרוש יוער, כי דין הבקשה להיד
# חות גם לעצם העניין. העונש שהוטל על המבקש בבית משפט השלום לתעבורה לא היה סביר ולא
#  הלם את מתחם הענישה המקובל בעבירות החמורות שביצע המבקש. עבירותיו החוזרות ונשנות
# של המבקש המחישו כי אין כל מקום להמשיך ולתת בו אמון או להקל בעונשו. לכל אלו יש לה
# וסיף את העובדה שלמבקש הרשעות קודמות בעבירות תעבורה. מכל הטעמים האמורים, אין כל מ
# קום ליתן רשות ערעור. אשר על כן, הבקשה למתן רשות ערעור נדחית. ניתנה היום, כ"א באל
# ול התשס"ז (4.9.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכה
#  וניסוח. 07064150_H01.doc /צש מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 3814, Trimmed Length: 1000):
# כי במקרה זה מתקיימות נסיבות חריגות המצדיקות לאפשר למבקש לחזור בו מהודייתו. המבקש
#  היה מיוצג בעת הדיון ואינו טוען כי נפל פגם בהודייתו או כי לא הבין את משמעותה. טע
# נתו, לפיה הרכב בו נהג אינו יכול לנסוע במהירות בה נטען שנסע, אינה מהווה נסיבה חרי
# גה המצדיקה את ביטול הודייתו, בייחוד לאור העובדה, כי טענה זו לא נטענה בעת הדיון ב
# בית-המשפט לתעבורה. טענותיו של בא-כוח המבקש לעניין גזר-הדין, אף הן דינן להידחות.
# הלכה היא, כי טענות בנוגע לחומרת העונש כשלעצמה, אינן מקימות עילה למתן רשות ערעור
# בפני בית-משפט זה, אלא בנסיבות של סטייה ניכרת ממדיניות הענישה (ראו רע"פ 1174/97 ע
# זרא רפאלי נ\' מדינת ישראל (לא פורסם); רע"פ 7201/97 דב בשירי נ\' היועץ המשפטי לממ
# שלה (לא פורסם)). אף לגופו של עניין לא מצאתי מקום להתערב בעונש שהוטל על המבקש וזא
# ת לאור עברו התעבורתי הכבד והעובדה כי הערכאות הקודמות לקחו בחשבון את נסיבותיו האי
# שיות בעת גזירת עונשו. אשר-על-כן, הבקשה למתן רשות ערעור נדחית. ניתנה היום, ט\' בש
# בט תשס"ז (28.1.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכה
#  וניסוח. 07008250_H01.doc /צש מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 12969, Trimmed Length: 1000):
# וסים, למרבה הצער, מצבים כאלה. אך משקבעה הערכאה הדיונית ממצאים עובדתיים, שעל בסיס
# ם חושבה התאונה כניתנת למניעה, ובית משפט שלערעור שב ונדרש לכך ואישר את מסקנותיה,
# אין כל מקום להתערבות של בית משפט זה בממצאים אלה בגלגול שלישי. ט. אף לעניין העונש
#  לא ראיתי לנכון להתערב בתוצאה אליה הגיע בית המשפט שלערעור, ששקל היטב את השיקולים
#  לכאן ולכאן, וקיצר במחצית את עונש הפסילה. על הטרגדיה שבתאונות דרכים קטלניות אין
# צורך להכביר מלים; היא טרגדיה בראש וראשונה ולאין שיעור לקרבנות ועמם למשפחתם, אך ה
# יא גם מכה קשה, אולי בל תימחה, לנהגים – לרובם, למי שהם אנשים נורמטיביים; אך העונש
#  העיקרי שהושת על המבקש – שישה חודשי מאסר בעבודות שירות – אינו במידרג הגבוה. י. א
# ין בידי איפוא להיעתר לבקשה. הואיל ולא ניתן עיכוב ביצוע בעניין עבודות השירות, אני
#  יוצא מהנחה כי המבקש החל בהן (אם לא כן כמובן תימסר הודעה). הפסילה תחל מיום 1.8.0
# 7, על מנת לאפשר למבקש בנסיבותיו המשפחתיות להתארגן כראוי. ניתנה היום, כ"ט בתמוז ת
# שס"ז (15.7.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכה וני
# סוח. 07041800_T04.doc מפ + הג מרכז מידע,
# ##*******************************************************####
# Trimmed Text (Original Length: 2530, Trimmed Length: 1000):
# ין מקום להתערב בעונש שנגזר לו, המורכב למעשה אך ורק מעונשי מאסר על תנאי שהופעלו.
# 3. בבקשה המונחת בפני עותר המבקש ליתן לו רשות לערער. לטענתו, נגזר עונשו לשבט רק מ
# חמת מצבו הכלכלי הקשה, ולא ניתן משקל לעובדה שהוא עבר תהליך שיקומי ארוך טווח. עוד
# ציין המבקש, כי הוא מועסק במפעל מתכת אשר מתעתד לייצא סחורה בהיקפים גדולים בתקופה
# הקרובה, ונוכחותו במקום העבודה חיונית. 4. דין הבקשה להידחות. ככלל, אין חומרת העונ
# ש מקימה עילה לקיומו של דיון נוסף בפני ערכאה שלישית (רע"פ 10231/03 קורן נ\' מדינת
#  ישראל, פ"ד נח(1) 646 (2003)), ואף שלכלל זה נקבעו חריגים, לא מצאתי כי הבקשה הנוכ
# חית נמנית על אותם חריגים. כך או כך, שתי ערכאות נתנו את דעתן לעניינו של המבקש, אש
# ר חטא לא אחת באלימות כלפי בת-זוגו, ומצאו כי אין מקום להאריך את המאסרים המותנים.
# לא סברתי כי באותה מסקנה נפלה שגגה, ולפיכך גם לא מצאתי כי הוכחה עילה לקיומו של ער
# עור נוסף. הבקשה נדחית, ועימה נדחית הבקשה לעיכוב ביצוע העונש. ניתנה היום, ט"ז בחש
# ון תשס"ח (28.10.2007). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 07088800_H01.doc שצ מרכז מידע,
# ##*******************************************************####
# הקובץ נשמר בהצלחה בנתיב: final_trimmed_data.csv
# <ipython-input-88-32142b05763e>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["גוף המסמך"] = data["גוף המסמך"].apply(trim_text)

# %% [markdown]
# ### Embedding

# %%
from sklearn.metrics import precision_recall_curve, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, make_scorer
from sklearn.model_selection import cross_val_predict, cross_validate
import joblib


# עדכון עמודת המטרה ואימבדינג לאחר חיתוך הטקסטים
y = data["binary_outcome"].values
embeddings = np.array([get_embeddings(text) for text in data["גוף המסמך"]])

# %% [markdown]
# ### Train and fit

# %%
from imblearn.under_sampling import RandomUnderSampler
import pandas as pd

# חישוב הכמות הנדרשת לכיתה 0 בהתאם לכמות כיתה 1
class_1_count = sum(y == 1)
class_0_count = int(class_1_count * (65 / 35))  # חישוב כמות כיתה 0 ל-65%

# הגדרת יחס חדש ל-undersampler
sampling_strategy = {0: class_0_count, 1: class_1_count}

# הגדרת undersampler עם היחס המחושב
undersampler = RandomUnderSampler(sampling_strategy=sampling_strategy, random_state=42)
X_resampled, y_resampled = undersampler.fit_resample(embeddings, y)

# בדיקת הכמויות אחרי undersampling
print("כמויות אחרי undersampling:")
print(pd.Series(y_resampled).value_counts())
print("יחס אחרי undersampling:")
print(pd.Series(y_resampled).value_counts(normalize=True))

# undersampler = RandomUnderSampler(sampling_strategy=0.55, random_state=42)
# X_resampled, y_resampled = undersampler.fit_resample(embeddings, y)

# שמירת אינדקסים מקוריים
resampled_indices = undersampler.sample_indices_
joblib.dump(resampled_indices, 'resampled_indices.pkl')

# ווידוא התאמה: מיפוי y_resampled לעמודת binary_outcome
binary_outcome_resampled = data.iloc[resampled_indices]["binary_outcome"].values
if not np.array_equal(y_resampled, binary_outcome_resampled):
    raise ValueError("Mismatch between y_resampled and resampled binary_outcome values!")

# הגדרת מסווג לוגיסטי עם משקל של 3 עבור קלאס 1
classifier = LogisticRegression(random_state=42, max_iter=1000, class_weight={0: 1, 1: 3})

# התאמת המודל לנתונים המאוזנים
classifier.fit(X_resampled, y_resampled)

# הגדרת מדדים לקרוס ולידציה
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, pos_label=1),
    'recall': make_scorer(recall_score, pos_label=1),
    'f1': make_scorer(f1_score, pos_label=1)
}

# ביצוע Cross Validation
cv_results = cross_validate(classifier, X_resampled, y_resampled, cv=5, scoring=scoring)

# חיזוי תוויות על כל קפל לצורך קונפיושן מטריקס
y_pred = cross_val_predict(classifier, X_resampled, y_resampled, cv=5)
conf_matrix = confusion_matrix(y_resampled, y_pred)

# הדפסת התוצאות
print("Cross-Validation Accuracy:", cv_results['test_accuracy'])
print("Mean Accuracy:", cv_results['test_accuracy'].mean())
print("Cross-Validation Precision for Class 1:", cv_results['test_precision'])
print("Mean Precision for Class 1:", cv_results['test_precision'].mean())
print("Cross-Validation Recall for Class 1:", cv_results['test_recall'])
print("Mean Recall for Class 1:", cv_results['test_recall'].mean())
print("Cross-Validation F1 Score for Class 1:", cv_results['test_f1'])
print("Mean F1 Score for Class 1:", cv_results['test_f1'].mean())

tn, fp, fn, tp = conf_matrix.ravel()

# הדפסת הקונפיושן מטריקס עם תוויות
print("Confusion Matrix with Labels:")
print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"True Positives (TP): {tp}")

print("\nConfusion Matrix:")
print(f"[[{tn} {fp}]")
print(f" [{fn} {tp}]]")

# --- לוגיקה למציאת threshold אופטימלי ---
predicted_probabilities = classifier.predict_proba(X_resampled)[:, 1]
precision, recall, thresholds = precision_recall_curve(y_resampled, predicted_probabilities)
f1_scores = 2 * (precision * recall) / (precision + recall)
optimal_threshold = thresholds[np.argmax(f1_scores)]
print(f"Threshold אופטימלי לפי F1 Score: {optimal_threshold}")

# שמירת יחס הכיתות המקורי
class_ratio_original = sum(y == 1) / len(y)
print(f"יחס כיתות מקורי (Class 1): {class_ratio_original:.2f}")

# --- שמירת משאבים ---
joblib.dump(classifier, 'classifier_model.pkl')
joblib.dump(optimal_threshold, 'optimal_threshold.pkl')
joblib.dump(class_ratio_original, 'class_ratio_original.pkl')

print("המודל והמשאבים נשמרו בהצלחה.")
# Out:
# כמויות אחרי undersampling:
# 0.0    79
# 1.0    43
# Name: count, dtype: int64
# יחס אחרי undersampling:
# 0.0    0.647541
# 1.0    0.352459
# Name: proportion, dtype: float64
# Cross-Validation Accuracy: [0.84       0.96       1.         0.875      0.83333333]
# Mean Accuracy: 0.9016666666666666
# Cross-Validation Precision for Class 1: [0.77777778 1.         1.         0.77777778 0.72727273]
# Mean Precision for Class 1: 0.8565656565656565
# Cross-Validation Recall for Class 1: [0.77777778 0.88888889 1.         0.875      0.88888889]
# Mean Recall for Class 1: 0.8861111111111111
# Cross-Validation F1 Score for Class 1: [0.77777778 0.94117647 1.         0.82352941 0.8       ]
# Mean F1 Score for Class 1: 0.8684967320261437
# Confusion Matrix with Labels:
# True Negatives (TN): 72
# False Positives (FP): 7
# False Negatives (FN): 5
# True Positives (TP): 38
#
# Confusion Matrix:
# [[72 7]
#  [5 38]]
# Threshold אופטימלי לפי F1 Score: 0.6485472225653068
# יחס כיתות מקורי (Class 1): 0.06
# המודל והמשאבים נשמרו בהצלחה.

# %% [markdown]
# ### FN print

# %%
# חיזוי תוויות על כל קפל לצורך זיהוי FN
y_pred = cross_val_predict(classifier, X_resampled, y_resampled, cv=5)

# איתור האינדקסים של FN - תווית אמיתית היא 1 והתחזית היא 0
fn_indices = np.where((y_resampled == 1) & (y_pred == 0))[0]

# מיפוי האינדקסים של FN לאינדקסים המקוריים של הנתונים
original_fn_indices = resampled_indices[fn_indices]

# קריאת פסקי הדין והערכים בעמודות "Outcome of case", "binary_outcome", ו-"Predicted" עבור הדוגמאות שמזוהות כ-FN
false_negative_rows = data.iloc[original_fn_indices]
false_negative_predicted = y_pred[fn_indices]  # התחזיות של המודל עבור FN

# ווידוא סינכרון מוחלט של האינדקסים
if len(false_negative_rows) != len(false_negative_predicted):
    raise ValueError("Mismatch between FN rows and predicted labels!")

# הדפסת פסקי הדין של FN בצורה מפורמטת עם הערכים המקוריים והתחזית להשוואה
print("False Negative Cases (True Label: 1, Predicted Label: 0):")
print("=" * 80)

for i, (index, row, predicted) in enumerate(zip(original_fn_indices, false_negative_rows.iterrows(), false_negative_predicted), 1):
    _, row_data = row
    print(f"\nCase {i}:")
    print("-" * 80)
    print("Index in Original Data:")
    print(index)
    print("\nOriginal Outcome of Case:")
    print(row_data["Outcome of case"])
    print("\nBinary Outcome (True Label):")
    print(row_data["binary_outcome"])
    print("\nPredicted Label:")
    print(predicted)
    print("\nDocument Body:")
    formatted_text = "\n".join(row_data["גוף המסמך"][j:j + 80] for j in range(0, len(row_data["גוף המסמך"]), 80))
    print(formatted_text)
    print("-" * 80)

print("=" * 80)
# Out:
# False Negative Cases (True Label: 1, Predicted Label: 0):
# ================================================================================
#
# Case 1:
# --------------------------------------------------------------------------------
# Index in Original Data:
# 3
#
# Original Outcome of Case:
# G A
#
# Binary Outcome (True Label):
# 1.0
#
# Predicted Label:
# 0.0
#
# Document Body:
#  הרשויות בעניינם של המבקשים אף הוא אינו משביערצון. במקביל להתמשכות השימוש הבלתי
# חוקי במבנההמרכול נעשו נסיונות מצד המבקשים לקבל היתר לשימוש חורג. הוועדה המקומית
# והמרחביתלכאורה לא התנגדו למתן ההיתר אלא היתנו את החלטתם בתנאים. אחד התנאים היה ק
# בלתהסכמת בעלים של מנהל מקרקעי ישראל, ומטעמה של הוועדה המרחבית היתה פניה למנהלמקר
# קעי ישראל בעניין זה. המבקשים התדפקו שנים על דלתות המנהל ואין כל הסבר לכךשתהליך ק
# בלת אישור המנהל והסכמתו לבקשת ההיתר התמשך תקופה כה ארוכה. על פני הדבריםנראה הדבר
#  כהליך ממושך ללא הסבר. בשים לב לכך ששאלה זו לא התלבנה בפנינו ולכך שמנהלמקרקעי יש
# ראל אינו מיוצג בהליך שלפנינו, איננו מסיקים כל מסקנה, כמובן, בעניין זה.אין לנו אל
# א לצפות כי המבקשים יכבדו את הצו שהושת עליהם לאלתר, וימנעו מלעשותשימוש במבנה שברש
# ותם בניגוד לחוק. הרשויות מצידן יפעלו במהירות הראויה כדי לבדוקאת עניינם באופן תקי
# ן וראוי. הבקשה נדחית. ניתנה היום, א\' בחשון התשס"ז(23.10.2006), בפני באי כוח הצד
# דים. ה נ ש י א ה ש ופ ט ש ו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 04001100_N07.doc דזמרכז מידע,
# --------------------------------------------------------------------------------
#
# Case 2:
# --------------------------------------------------------------------------------
# Index in Original Data:
# 465
#
# Original Outcome of Case:
# G A with apellee's consent
#
# Binary Outcome (True Label):
# 1.0
#
# Predicted Label:
# 0.0
#
# Document Body:
# בגדרם של אותם חריגים המצדיקים עיכוב ביצועו של צו ההריסה. באשר לסיכויי הערעור, אל
# ו על פניו הינם נמוכים, שלא לומר קלושים. בית המשפט המחוזי דחה, בהחלטה מנומקת ומבו
# ססת, את כל הטענות העיקריות שהעלה המערער בבקשתו, תוך שהוא קובע כי לא נראה באופק כ
# ל סיכוי להכשיר את הבנייה הבלתי-חוקית נשוא צו ההריסה. בצדק, קבע בית המשפט המחוזי,
#  כי סלילתו של משטח האספלט מהווה עבודה הטעונה היתר בניה לפי סעיף 145 לחוק (ראו גם
# , רע"פ 2809/05 טסה נ\' מדינת ישראל (לא פורסם)). מאחר והבנייה בה מדובר נעשתה בלא
# היתר, על קרקע שייעודה הינו חקלאי, נדמה, ולוּ לכאורה, כי ההחלטה לאשר את ביצוע צו
# ההריסה בדין יסודה. זאת, בפרט לאור הקביעה כי לא הוכח שבזמן הקרוב עשוי ייעוד הקרקע
#  להשתנות. עיינתי אף בשאר הטענות של המערער ואיני סבור כי סיכוייהן להתקבל גבוהים.
# באשר למאזן הנוחות, לא שוכנעתי כי הריסת משטח האספלט עשויה לגרום למערער ולבני משפח
# תו נזק בלתי הפיך. לאור כל האמור דעתי היא כי דין הערעור להידחות. ניתן היום, י\' ב
# סיוון תשס"ז (27.5.07). ש ו פ ט _________________________ העותק כפוף לשינויי עריכ
# ה וניסוח. 07042430_H03.doc קק מרכז מידע,
# --------------------------------------------------------------------------------
#
# Case 3:
# --------------------------------------------------------------------------------
# Index in Original Data:
# 51
#
# Original Outcome of Case:
# G A at most- defendant was acquitted of one felony with plaintiff's consent. The sunction remained.
#
# Binary Outcome (True Label):
# 1.0
#
# Predicted Label:
# 0.0
#
# Document Body:
# מתחם הענישה המקובל בעבירות מהסוג שביצע ונסיבות המקרה אינן מצדיקות התערבותבית-משפ
# ט זה. לא זו בלבד שהמבקש התעלם מעונשי הפסילה שנגזרו עליו ושב לאחוז בהגה,ללא רישיו
# ן נהיגה וביטוח תקפים, אלא שהוסיף לכך גם את העבירה החמורה של נהיגהבשכרות. עם זאת,
#  בכל הנוגע לעבירה של סירובלהיבדק, לפי תקנה 169ו לתקנות התעבורה, לאור הסכמתה של ה
# משיבה, הוחלט לדון בבקשהכאילו ניתנה רשות ערעור וכאילו הוגש ערעור על-פי הרשות שנית
# נה, ולזכות את המבקשמעבירה זו, מתוקף סמכותנו לפי סעיף 205 לחוק סדר הדין הפלילי [נ
# וסח משולב],תשמ"ב-1982. עם זאת, לאור התעלמותו של בית-המשפט לתעבורה מעבירה זו בעתג
# זירת-דינו של המבקש, הרי שאין לכך השפעה על העונש שהוטל על המבקש. בכפוף לאמור לעיל
# , הבקשה למתן רשות ערעורנדחית. החלטתי מיום 21.11.2005 בעניין עיכובביצוע עונש המאס
# ר – מבוטלת. על המבקש להתייצב ביום 4.7.2006, לאיאוחר מהשעה 10:00, במזכירות בית-המ
# שפט המחוזי בתל-אביב-יפו, לשם תחילת ריצועונשו. ניתנה היום, ט"ז בסיוון תשס"ו(12.6.
# 2006). ש ו פ ט ש ו פט ת ש ו פ ט _________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 05107580_H06.doc דממרכז מידע,
# --------------------------------------------------------------------------------
#
# Case 4:
# --------------------------------------------------------------------------------
# Index in Original Data:
# 279
#
# Original Outcome of Case:
# G A
#
# Binary Outcome (True Label):
# 1.0
#
# Predicted Label:
# 0.0
#
# Document Body:
# ['החלטה בתיק רע"פ 3884/06 בבית המשפט העליון רע"פ 3884/06 - ו\' בפני: כבוד השופטת
#  ע\' ארבל המבקש: פיטר עספור נגד המשיבה: מדינת ישראל בקשה לדחיית ריצוי עונש המאסר
#  בשם המבקש: עו"ד מ\' חסאן בשם המשיבה: עו"ד א\' וינשל החלטה בהסכמת המשיבה ידחה רי
# צוי עונשו של המבקש ליום 7.3.07. המקש יתייצב ביום זה עד שעה 10:00 במזכירות הפלילי
# ת בבית המשפט המחוזי בירושלים. ניתנה היום, ד\' באדר תשס"ז (22.2.07). ש ו פ ט ת __
# _______________________ העותק כפוף לשינויי עריכה וניסוח. 06038840_B07.doc עכ מרכ
# ז מידע,
# --------------------------------------------------------------------------------
#
# Case 5:
# --------------------------------------------------------------------------------
# Index in Original Data:
# 328
#
# Original Outcome of Case:
# G A Denied at most
#
# Binary Outcome (True Label):
# 1.0
#
# Predicted Label:
# 0.0
#
# Document Body:
# וזכרים לעיל,דין בקשת רשות הערעור להידחות. עניינם של המבקשים כבר נדון בפני שתיערכ
# אות. כידוע, הכלל הנוהג הינו, כי הרשות לערעור שני, אינה ניתנת כדבר שבשגרה,אלא מוג
# בלת למקרים המעוררים שאלה בעלת חשיבות משפטית או ציבורית, החורגת מעניינםהפרטני של
# הצדדים. בענייננו, בקשת רשות הערעור איננה מעוררת כל שאלה משפטיתעקרונית שכזו והמבק
# ש לא הצביע על עילה המצדיקה דיון בגלגול שלישי, בהתאם להלכת חניון חיפה,כאמור. יש ל
# דחות את טענת היעדר ההנמקה. בענייננו,בית-המשפט המחוזי נימק בקצרה את מסקנתו וממנה
# למדים אנו, כי הוא אכן בחן אתהממצאים העובדתיים והצדיק את החלטתו של בית-המשפט לעני
# ינים מקומיים. אין לצפות, כיבכל מקרה, ערכאת הערעור תחזור שוב על כל נימוקי הערכאה
# הדיונית, מקום שהיא מסכימהעם ממצאיה, ולא מצאה כל פסול במסקנותיה (ראו גם רע"א 8996
# /04 שכטר נ\' נציגות הבית המשותף, פ"ד נט(5)17). מטעמים אלה כולם, בקשת רשות הערעור
# נדחית, למעט בנוגע לדו"ח מספר 72653/2/04 כאמור לעיל. ניתן היום, כ"ו באב תשס"ו (20
# .8.06). ש ו פ ט ת ש ופ ט ש ו פ ט ________________________העותק כפוף לשינויי עריכ
# ה וניסוח. 06029450_H05.doc רגמרכז מידע,
# --------------------------------------------------------------------------------
# ================================================================================
